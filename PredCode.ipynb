# %%
from pyspark.sql import SparkSession
from pyspark.sql import SQLContext
from pyspark.sql.functions import col, avg, when
from pyspark.mllib.regression import LabeledPoint
from pyspark.mllib.tree import DecisionTree

import time
import sys
import os
import glob
import hdf5_getters
import re

# (8 cores, 16gb per machine) x 5 = 40 cores

# New API
spark_session = SparkSession\
        .builder\
        .master("spark://192.168.1.79:7077") \
        .appName("SongHotness")\
        .config("spark.dynamicAllocation.enabled", True)\
        .config("spark.shuffle.service.enabled", True)\
        .config("spark.dynamicAllocation.executorIdleTimeout","30s")\
        .config("spark.executor.cores",1)\
        .getOrCreate()

# Old API (RDD)
spark_context = spark_session.sparkContext
sqlContext = SQLContext(spark_context)

def rowUnpack(df):
        results={}
        for i in df:
            results.update(i.asDict())
        return(results)

# %%
class Song:
    songCount = 0
    # songDictionary = {}

    def __init__(self, songID):
        self.id = songID
        Song.songCount += 1
        # Song.songDictionary[songID] = self

        self.albumName = None
        self.albumID = None
        self.artistID = None
        self.artistLatitude = None
        self.artistLocation = None
        self.artistLongitude = None
        self.artistName = None
        self.danceability = None
        self.duration = None
        self.energy = None
        self.genreList = []
        self.keySignature = None
        self.keySignatureConfidence = None
        self.lyrics = None
        self.popularity = None
        self.songhotttnesss = None
        self.tempo = None
        self.timeSignature = None
        self.timeSignatureConfidence = None
        self.title = None
        self.year = None

    def displaySongCount(self):
        print("Total Song Count %i" % Song.songCount)

    def displaySong(self):
        print("ID: %s" % self.id)

# %%
    
"""
Original:

Alexis Greenstreet (October 4, 2015) University of Wisconsin-Madison

This code is designed to convert the HDF5 files of the Million Song Dataset
to a CSV by extracting various song properties.

The script writes to a "SongCSV.csv" in the directory containing this script.

Please note that in the current form, this code only extracts the following
information from the HDF5 files:
AlbumID, AlbumName, ArtistID, ArtistLatitude, ArtistLocation,
ArtistLongitude, ArtistName, Danceability, Duration, KeySignature,
KeySignatureConfidence, SongID, Tempo, TimeSignature,
TimeSignatureConfidence, Title, and Year.

This file also requires the use of "hdf5_getters.py", written by
Thierry Bertin-Mahieux (2010) at Columbia University

Credit:
This HDF5 to CSV code makes use of the following example code provided
at the Million Song Dataset website 
(Home>Tutorial/Iterate Over All Songs, 
http://labrosa.ee.columbia.edu/millionsong/pages/iterate-over-all-songs),
Which gives users the following code to get all song titles:

#import os
#import glob
#import hdf5_getters
#def get_all_titles(basedir,ext='.h5') :
#    titles = []
#   for root, dirs, files in os.walk(basedir):
#        files = glob.glob(os.path.join(root,'*'+ext))
#        for f in files:
#            h5 = hdf5_getters.open_h5_file_read(f)
#            titles.append( hdf5_getters.get_title(h5) )
#            h5.close()
#   return titles 
"""

"""This code has been modified for python3 compatibility by Karthik Nair(28 May 2019) of Uppsala University (github.com/karnair)"""
"""This code has been adapted for conversion of .h5 files to PySpark Dataframe by Karthik Nair(3 June 2019) of Uppsala University (github.com/karnair)"""
# Out:
# 'This code has been adapted for conversion of .h5 files to PySpark Dataframe by Karthik Nair(3 June 2019) of Uppsala University (github.com/karnair)'

# %%
def h5toPysDf():
    
   
    song_number = []
    album_id = []
    artist_latitude = []
    artist_location = []
    artist_longitude = []
    artist_name =[]
    danceability = []
    duration = []
    energy = []
    key_signature = []
    key_signature_confidence = []
    song_id = []
    tempo = []
    song_hotttnesss = []
    time_signature = []
    time_signature_confidence = []
    title = []
    year = []
    
    
    
    csvRowString = ("SongID,AlbumID,ArtistLatitude,ArtistLocation,"+
            "ArtistLongitude,ArtistName,Danceability,Duration,Energy,KeySignature,"+
            "KeySignatureConfidence,SongHotttnesss,Tempo,TimeSignature,TimeSignatureConfidence,"+
            "Title,Year")
    
    csvAttributeList = re.split('\W+', csvRowString)
    
    for i, v in enumerate(csvAttributeList):
        csvAttributeList[i] = csvAttributeList[i].lower()
        csvRowString = ""
    
    basedir = "/home/ubuntu/MillionSongSubset/data" # "." As the default means the current directory
    ext = ".h5"
    
    for root, dirs, files in os.walk(basedir):        
        files = glob.glob(os.path.join(root,'*'+ext))
        for f in files:
            print(f)

            songH5File = hdf5_getters.open_h5_file_read(f)
            song = Song(str(hdf5_getters.get_song_id(songH5File)))

            testDanceability = hdf5_getters.get_danceability(songH5File)
            # print type(testDanceability)
            # print ("Here is the danceability: ") + str(testDanceability)

            #song.artistID = str(hdf5_getters.get_artist_id(songH5File))
            song.albumID = str(hdf5_getters.get_release_7digitalid(songH5File))
            #song.albumName = str(hdf5_getters.get_release(songH5File))
            song.artistLatitude = str(hdf5_getters.get_artist_latitude(songH5File))
            song.artistLocation = str(hdf5_getters.get_artist_location(songH5File))
            song.artistLongitude = str(hdf5_getters.get_artist_longitude(songH5File))
            song.artistName = str(hdf5_getters.get_artist_name(songH5File))
            song.danceability = float(hdf5_getters.get_danceability(songH5File))
            song.duration = float(hdf5_getters.get_duration(songH5File))
            song.energy = float(hdf5_getters.get_energy(songH5File))
            # song.setGenreList()
            song.keySignature = float(hdf5_getters.get_key(songH5File))
            song.keySignatureConfidence = float(hdf5_getters.get_key_confidence(songH5File))
            # song.lyrics = None
            # song.popularity = None
            song.tempo = float(hdf5_getters.get_tempo(songH5File))
            song.songhotttnesss = float(hdf5_getters.get_song_hotttnesss(songH5File))
            song.timeSignature = float(hdf5_getters.get_time_signature(songH5File))
            song.timeSignatureConfidence = float(hdf5_getters.get_time_signature_confidence(songH5File))
            song.title = str(hdf5_getters.get_title(songH5File))
            song.year = str(hdf5_getters.get_year(songH5File))
            
            
            
            #csvRowString += str(song.songCount) + ","
            song_number.append(song.songCount)

            for attribute in csvAttributeList:
                # print "Here is the attribute: " + attribute + " \n"

                if attribute == 'AlbumID'.lower():
                    #csvRowString += song.albumID
                    album_id.append(song.albumID)
                elif attribute == 'ArtistLatitude'.lower():
                    latitude = song.artistLatitude
                    if latitude == 'nan':
                        latitude = ''
                    artist_latitude.append(latitude)
                elif attribute == 'ArtistLocation'.lower():
                    location = song.artistLocation
                    location = location.replace(',','')
                    artist_location.append(location) 
                elif attribute == 'ArtistLongitude'.lower():
                    longitude = song.artistLongitude
                    if longitude == 'nan':
                        longitude = ''
                    artist_longitude.append(longitude)   
                elif attribute == 'ArtistName'.lower():
                    artist_name.append(song.artistName)
                elif attribute == 'Danceability'.lower():
                    danceability.append(song.danceability)
                elif attribute == 'Duration'.lower():
                    duration.append(song.duration)
                elif attribute == 'Energy'.lower():
                    energy.append(song.energy)
                elif attribute == 'KeySignature'.lower():
                    key_signature.append(song.keySignature)
                elif attribute == 'KeySignatureConfidence'.lower():
                    # print "key sig conf: " + song.timeSignatureConfidence                                 
                    key_signature_confidence.append(song.keySignatureConfidence)
                elif attribute == 'SongID'.lower():
                    song_id.append(song.id)
                elif attribute == 'Tempo'.lower():
                    # print "Tempo: " + song.tempo
                    tempo.append(song.tempo)
                elif attribute == 'SongHotttnesss'.lower():
                    song_hotttnesss.append(song.songhotttnesss)
                elif attribute == 'TimeSignature'.lower():
                    time_signature.append(song.timeSignature)
                elif attribute == 'TimeSignatureConfidence'.lower():
                    # print "time sig conf: " + song.timeSignatureConfidence                                   
                    time_signature_confidence.append(song.timeSignatureConfidence)
                elif attribute == 'Title'.lower():
                    title.append(song.title)
                elif attribute == 'Year'.lower():
                    year.append(song.year)
                #"""else:
                 #   csvRowString += "Erm. This didn't work. Error. :( :(\n" """"

                #csvRowString += ","
            songH5File.close()
    pysp_df = sqlContext.createDataFrame(zip(song_number, album_id, artist_latitude, artist_location, artist_longitude, artist_name, danceability, duration, energy, key_signature, key_signature_confidence, song_id, tempo, song_hotttnesss, time_signature, time_signature_confidence, title, year), schema=['song_number', 'album_id', 'artist_latitude', 'artist_location', 'artist_longitude', 'artist_name', 'danceability', 'duration', 'energy', 'key_signature', 'key_signature_confidence', 'song_id', 'tempo', 'song_hotttnesss', 'time_signature', 'time_signature_confidence', 'title', 'year'])
    return pysp_df

# %%
#song_number, album_id, artist_latitude, artist_location, artist_longitude, artist_name, danceability, duration, energy, key_signature, key_signature_confidence, song_id, tempo, song_hotttnesss, time_signature, time_signature_confidence, title, year = main()
msd_df = h5toPysDf()
# Out:
# /home/ubuntu/MillionSongSubset/data/B/B/T/TRBBTUV128F933D382.h5
# /home/ubuntu/MillionSongSubset/data/B/B/T/TRBBTJH128F1476BC7.h5
# /home/ubuntu/MillionSongSubset/data/B/B/T/TRBBTSI128E0790E7B.h5
# /home/ubuntu/MillionSongSubset/data/B/B/T/TRBBTDV128F934F6B1.h5
# /home/ubuntu/MillionSongSubset/data/B/B/T/TRBBTQB128F92FAB03.h5
# /home/ubuntu/MillionSongSubset/data/B/B/T/TRBBTFO128EF345397.h5
# /home/ubuntu/MillionSongSubset/data/B/B/T/TRBBTZW12903CE7495.h5
# /home/ubuntu/MillionSongSubset/data/B/B/T/TRBBTJG12903CD5B47.h5
# /home/ubuntu/MillionSongSubset/data/B/B/T/TRBBTOM128F42309C2.h5
# /home/ubuntu/MillionSongSubset/data/B/B/T/TRBBTUD128F42A10A3.h5
# /home/ubuntu/MillionSongSubset/data/B/B/T/TRBBTLA128F4226907.h5
# /home/ubuntu/MillionSongSubset/data/B/B/S/TRBBSFL128F931798C.h5
# /home/ubuntu/MillionSongSubset/data/B/B/S/TRBBSBF128F14687A4.h5
# /home/ubuntu/MillionSongSubset/data/B/B/S/TRBBSKC128F1496C4E.h5
# /home/ubuntu/MillionSongSubset/data/B/B/S/TRBBSGI128F9309855.h5
# /home/ubuntu/MillionSongSubset/data/B/B/S/TRBBSZN128F930E4E7.h5
# /home/ubuntu/MillionSongSubset/data/B/B/S/TRBBSSU128F4265E16.h5
# /home/ubuntu/MillionSongSubset/data/B/B/S/TRBBSXW12903CEB61D.h5
# /home/ubuntu/MillionSongSubset/data/B/B/B/TRBBBKS12903CDFCF4.h5
# /home/ubuntu/MillionSongSubset/data/B/B/B/TRBBBFO128F931535D.h5
# /home/ubuntu/MillionSongSubset/data/B/B/B/TRBBBUG128F148D65B.h5
# /home/ubuntu/MillionSongSubset/data/B/B/B/TRBBBLA128F424E963.h5
# /home/ubuntu/MillionSongSubset/data/B/B/B/TRBBBMT128F42A0A4E.h5
# /home/ubuntu/MillionSongSubset/data/B/B/B/TRBBBVC128F429AB66.h5
# /home/ubuntu/MillionSongSubset/data/B/B/B/TRBBBEA128F93391BA.h5
# /home/ubuntu/MillionSongSubset/data/B/B/B/TRBBBOA128F42624DA.h5
# /home/ubuntu/MillionSongSubset/data/B/B/J/TRBBJVD128E07826F3.h5
# /home/ubuntu/MillionSongSubset/data/B/B/J/TRBBJFZ12903D114AF.h5
# /home/ubuntu/MillionSongSubset/data/B/B/J/TRBBJAJ128F425DA40.h5
# /home/ubuntu/MillionSongSubset/data/B/B/J/TRBBJPY128F92F31E0.h5
# /home/ubuntu/MillionSongSubset/data/B/B/J/TRBBJST12903CEC7DC.h5
# /home/ubuntu/MillionSongSubset/data/B/B/J/TRBBJUQ128F92D5776.h5
# /home/ubuntu/MillionSongSubset/data/B/B/J/TRBBJTX12903CFC111.h5
# /home/ubuntu/MillionSongSubset/data/B/B/J/TRBBJFO12903D074EE.h5
# /home/ubuntu/MillionSongSubset/data/B/B/J/TRBBJJI128F4299711.h5
# /home/ubuntu/MillionSongSubset/data/B/B/J/TRBBJFM128F427ADEC.h5
# /home/ubuntu/MillionSongSubset/data/B/B/J/TRBBJLK128F427FCDE.h5
# /home/ubuntu/MillionSongSubset/data/B/B/J/TRBBJVE128F9303F10.h5
# /home/ubuntu/MillionSongSubset/data/B/B/J/TRBBJKY128F931FB24.h5
# /home/ubuntu/MillionSongSubset/data/B/B/J/TRBBJBO128F92EB2C5.h5
# /home/ubuntu/MillionSongSubset/data/B/B/E/TRBBEQY128F42373AF.h5
# /home/ubuntu/MillionSongSubset/data/B/B/E/TRBBEJC128F4281471.h5
# /home/ubuntu/MillionSongSubset/data/B/B/E/TRBBEEP128F147F1BF.h5
# /home/ubuntu/MillionSongSubset/data/B/B/E/TRBBEHB128E0784F71.h5
# /home/ubuntu/MillionSongSubset/data/B/B/E/TRBBECU128F931E67C.h5
# /home/ubuntu/MillionSongSubset/data/B/B/E/TRBBEGG128F9314BAA.h5
# /home/ubuntu/MillionSongSubset/data/B/B/E/TRBBEAE128F429E371.h5
# /home/ubuntu/MillionSongSubset/data/B/B/E/TRBBEYU128F4235623.h5
# /home/ubuntu/MillionSongSubset/data/B/B/N/TRBBNCE128F4295D5E.h5
# /home/ubuntu/MillionSongSubset/data/B/B/N/TRBBNIV12903CD4755.h5
# /home/ubuntu/MillionSongSubset/data/B/B/N/TRBBNRP128F92EDD9D.h5
# /home/ubuntu/MillionSongSubset/data/B/B/N/TRBBNDS12903CBF924.h5
# /home/ubuntu/MillionSongSubset/data/B/B/N/TRBBNCR128F930B340.h5
# /home/ubuntu/MillionSongSubset/data/B/B/N/TRBBNKD128F92F251E.h5
# /home/ubuntu/MillionSongSubset/data/B/B/N/TRBBNHZ128F423E599.h5
# /home/ubuntu/MillionSongSubset/data/B/B/N/TRBBNNS128F931C83D.h5
# /home/ubuntu/MillionSongSubset/data/B/B/N/TRBBNPX12903CA5375.h5
# /home/ubuntu/MillionSongSubset/data/B/B/N/TRBBNML12903CBD2B3.h5
# /home/ubuntu/MillionSongSubset/data/B/B/N/TRBBNTP128F92D934C.h5
# /home/ubuntu/MillionSongSubset/data/B/B/N/TRBBNGV128F147EAFC.h5
# /home/ubuntu/MillionSongSubset/data/B/B/I/TRBBIHP128F92E40CA.h5
# /home/ubuntu/MillionSongSubset/data/B/B/I/TRBBIJM12903C9AB35.h5
# /home/ubuntu/MillionSongSubset/data/B/B/I/TRBBILK128F14A2FD6.h5
# /home/ubuntu/MillionSongSubset/data/B/B/I/TRBBIBE128F4226E29.h5
# /home/ubuntu/MillionSongSubset/data/B/B/I/TRBBIGE128F1491C45.h5
# /home/ubuntu/MillionSongSubset/data/B/B/I/TRBBIYI128F92E13CC.h5
# /home/ubuntu/MillionSongSubset/data/B/B/I/TRBBISD12903CF8B3E.h5
# /home/ubuntu/MillionSongSubset/data/B/B/I/TRBBIPG128F92FA94D.h5
# /home/ubuntu/MillionSongSubset/data/B/B/I/TRBBICL128F42ADFD3.h5
# /home/ubuntu/MillionSongSubset/data/B/B/I/TRBBILZ12903CB422C.h5
# /home/ubuntu/MillionSongSubset/data/B/B/I/TRBBIYX128F1497FF2.h5
# /home/ubuntu/MillionSongSubset/data/B/B/C/TRBBCZA128F146587F.h5
# /home/ubuntu/MillionSongSubset/data/B/B/C/TRBBCXH128E0790ACB.h5
# /home/ubuntu/MillionSongSubset/data/B/B/C/TRBBCCM128F932D71A.h5
# /home/ubuntu/MillionSongSubset/data/B/B/C/TRBBCFY128F9301C63.h5
# /home/ubuntu/MillionSongSubset/data/B/B/C/TRBBCUA128E078FA50.h5
# /home/ubuntu/MillionSongSubset/data/B/B/C/TRBBCVJ128F425BE2C.h5
# /home/ubuntu/MillionSongSubset/data/B/B/C/TRBBCJH128F930C970.h5
# /home/ubuntu/MillionSongSubset/data/B/B/C/TRBBCPJ12903CC529A.h5
# /home/ubuntu/MillionSongSubset/data/B/B/C/TRBBCBT12903CB0497.h5
# /home/ubuntu/MillionSongSubset/data/B/B/C/TRBBCOM128F92F1208.h5
# /home/ubuntu/MillionSongSubset/data/B/B/P/TRBBPPB128F14AB242.h5
# /home/ubuntu/MillionSongSubset/data/B/B/P/TRBBPGU12903CF7C25.h5
# /home/ubuntu/MillionSongSubset/data/B/B/P/TRBBPXP128F148511C.h5
# /home/ubuntu/MillionSongSubset/data/B/B/P/TRBBPPQ128F426C3D5.h5
# /home/ubuntu/MillionSongSubset/data/B/B/P/TRBBPSX128F93332EE.h5
# /home/ubuntu/MillionSongSubset/data/B/B/P/TRBBPGL128F933E34C.h5
# /home/ubuntu/MillionSongSubset/data/B/B/P/TRBBPYO128F426DF2A.h5
# /home/ubuntu/MillionSongSubset/data/B/B/L/TRBBLGX128F92D46B8.h5
# /home/ubuntu/MillionSongSubset/data/B/B/L/TRBBLNS12903CE5265.h5
# /home/ubuntu/MillionSongSubset/data/B/B/L/TRBBLTE128F42558EF.h5
# /home/ubuntu/MillionSongSubset/data/B/B/L/TRBBLAN128F93183E6.h5
# /home/ubuntu/MillionSongSubset/data/B/B/L/TRBBLUO12903CEDBD2.h5
# /home/ubuntu/MillionSongSubset/data/B/B/L/TRBBLCU128F423C5DA.h5
# /home/ubuntu/MillionSongSubset/data/B/B/L/TRBBLDK128F93443C0.h5
# /home/ubuntu/MillionSongSubset/data/B/B/L/TRBBLBI128F92EEF0F.h5
# /home/ubuntu/MillionSongSubset/data/B/B/L/TRBBLFA12903CDC496.h5
# /home/ubuntu/MillionSongSubset/data/B/B/L/TRBBLNE128F4256D3F.h5
# /home/ubuntu/MillionSongSubset/data/B/B/L/TRBBLXX128F92C3D8C.h5
# /home/ubuntu/MillionSongSubset/data/B/B/L/TRBBLYZ128F4269606.h5
# /home/ubuntu/MillionSongSubset/data/B/B/L/TRBBLUS128F4276631.h5
# /home/ubuntu/MillionSongSubset/data/B/B/L/TRBBLTV12903CC3C00.h5
# /home/ubuntu/MillionSongSubset/data/B/B/L/TRBBLOQ128F930C9DE.h5
# /home/ubuntu/MillionSongSubset/data/B/B/U/TRBBUBC128F148CBAA.h5
# /home/ubuntu/MillionSongSubset/data/B/B/U/TRBBUCK128F42AFAD6.h5
# /home/ubuntu/MillionSongSubset/data/B/B/U/TRBBUHZ128F428F001.h5
# /home/ubuntu/MillionSongSubset/data/B/B/U/TRBBUOJ128F92FC6F2.h5
# /home/ubuntu/MillionSongSubset/data/B/B/U/TRBBULA128F146E122.h5
# /home/ubuntu/MillionSongSubset/data/B/B/U/TRBBUPS12903CFC938.h5
# /home/ubuntu/MillionSongSubset/data/B/B/Q/TRBBQPP128F92EE611.h5
# /home/ubuntu/MillionSongSubset/data/B/B/Q/TRBBQMY128F9320AF7.h5
# /home/ubuntu/MillionSongSubset/data/B/B/Q/TRBBQVL128F93421CA.h5
# /home/ubuntu/MillionSongSubset/data/B/B/Q/TRBBQFV128F4252EFF.h5
# /home/ubuntu/MillionSongSubset/data/B/B/Q/TRBBQAV128F92E2000.h5
# /home/ubuntu/MillionSongSubset/data/B/B/Q/TRBBQGV12903CB5CD3.h5
# /home/ubuntu/MillionSongSubset/data/B/B/Q/TRBBQHG12903CB5AD2.h5
# /home/ubuntu/MillionSongSubset/data/B/B/Q/TRBBQYU128F4269447.h5
# /home/ubuntu/MillionSongSubset/data/B/B/Q/TRBBQJZ128F92C5AF2.h5
# /home/ubuntu/MillionSongSubset/data/B/B/F/TRBBFFE128F9347D66.h5
# /home/ubuntu/MillionSongSubset/data/B/B/F/TRBBFOT12903CBCB4F.h5
# /home/ubuntu/MillionSongSubset/data/B/B/F/TRBBFUA128F933AB95.h5
# /home/ubuntu/MillionSongSubset/data/B/B/F/TRBBFRR128F426CD17.h5
# /home/ubuntu/MillionSongSubset/data/B/B/F/TRBBFBZ128F42493ED.h5
# /home/ubuntu/MillionSongSubset/data/B/B/F/TRBBFHG128F932B9D6.h5
# /home/ubuntu/MillionSongSubset/data/B/B/F/TRBBFLM128F14AD269.h5
# /home/ubuntu/MillionSongSubset/data/B/B/F/TRBBFTS12903CDC3D9.h5
# /home/ubuntu/MillionSongSubset/data/B/B/F/TRBBFMN128F421AF38.h5
# /home/ubuntu/MillionSongSubset/data/B/B/V/TRBBVNR128E078E1E4.h5
# /home/ubuntu/MillionSongSubset/data/B/B/V/TRBBVDW128F932262A.h5
# /home/ubuntu/MillionSongSubset/data/B/B/V/TRBBVYI128F4291603.h5
# /home/ubuntu/MillionSongSubset/data/B/B/V/TRBBVBM128F92D07F1.h5
# /home/ubuntu/MillionSongSubset/data/B/B/V/TRBBVFB128F1461507.h5
# /home/ubuntu/MillionSongSubset/data/B/B/V/TRBBVDP128F92F28CF.h5
# /home/ubuntu/MillionSongSubset/data/B/B/V/TRBBVSO128F9341C12.h5
# /home/ubuntu/MillionSongSubset/data/B/B/V/TRBBVFT128F42ABB02.h5
# /home/ubuntu/MillionSongSubset/data/B/B/V/TRBBVBM128F4276D82.h5
# /home/ubuntu/MillionSongSubset/data/B/B/V/TRBBVAH128F4270300.h5
# /home/ubuntu/MillionSongSubset/data/B/B/V/TRBBVXL128F427C3F2.h5
# /home/ubuntu/MillionSongSubset/data/B/B/V/TRBBVPM12903CDB094.h5
# /home/ubuntu/MillionSongSubset/data/B/B/V/TRBBVTH128F92F3B6F.h5
# /home/ubuntu/MillionSongSubset/data/B/B/V/TRBBVYO128F146AEDC.h5
# /home/ubuntu/MillionSongSubset/data/B/B/R/TRBBRJN128F425C040.h5
# /home/ubuntu/MillionSongSubset/data/B/B/R/TRBBRME128F4276C73.h5
# /home/ubuntu/MillionSongSubset/data/B/B/R/TRBBRYI128F42370F5.h5
# /home/ubuntu/MillionSongSubset/data/B/B/R/TRBBRFQ12903CE2997.h5
# /home/ubuntu/MillionSongSubset/data/B/B/R/TRBBRVT128F428EA7A.h5
# /home/ubuntu/MillionSongSubset/data/B/B/R/TRBBRIQ128F9353B5C.h5
# /home/ubuntu/MillionSongSubset/data/B/B/R/TRBBRQE12903C9E587.h5
# /home/ubuntu/MillionSongSubset/data/B/B/R/TRBBREF128F933CCDD.h5
# /home/ubuntu/MillionSongSubset/data/B/B/R/TRBBRTY128F4260973.h5
# /home/ubuntu/MillionSongSubset/data/B/B/R/TRBBRRS128F4256EEF.h5
# /home/ubuntu/MillionSongSubset/data/B/B/R/TRBBRXN12903CBAE27.h5
# /home/ubuntu/MillionSongSubset/data/B/B/R/TRBBRXA12903CAB6C0.h5
# /home/ubuntu/MillionSongSubset/data/B/B/Y/TRBBYKP128F92D60F0.h5
# /home/ubuntu/MillionSongSubset/data/B/B/Y/TRBBYQM128F1468524.h5
# /home/ubuntu/MillionSongSubset/data/B/B/Y/TRBBYFJ128F42A22D4.h5
# /home/ubuntu/MillionSongSubset/data/B/B/Y/TRBBYWM128F9324A8B.h5
# /home/ubuntu/MillionSongSubset/data/B/B/Y/TRBBYGX12903CEF0BC.h5
# /home/ubuntu/MillionSongSubset/data/B/B/Y/TRBBYDT128F14805B4.h5
# /home/ubuntu/MillionSongSubset/data/B/B/Y/TRBBYST12903CE82DB.h5
# /home/ubuntu/MillionSongSubset/data/B/B/Y/TRBBYYL128F4236EBC.h5
# /home/ubuntu/MillionSongSubset/data/B/B/Y/TRBBYOI128F4256732.h5
# /home/ubuntu/MillionSongSubset/data/B/B/D/TRBBDLG128F9308703.h5
# /home/ubuntu/MillionSongSubset/data/B/B/D/TRBBDBV12903D00668.h5
# /home/ubuntu/MillionSongSubset/data/B/B/D/TRBBDPA12903CCCA06.h5
# /home/ubuntu/MillionSongSubset/data/B/B/D/TRBBDFG128F4229DE2.h5
# /home/ubuntu/MillionSongSubset/data/B/B/D/TRBBDDG128F14743AE.h5
# /home/ubuntu/MillionSongSubset/data/B/B/D/TRBBDIU128F1496C52.h5
# /home/ubuntu/MillionSongSubset/data/B/B/D/TRBBDJI12903CF10AB.h5
# /home/ubuntu/MillionSongSubset/data/B/B/D/TRBBDXO128F14A4737.h5
# /home/ubuntu/MillionSongSubset/data/B/B/D/TRBBDAH128F92E625E.h5
# /home/ubuntu/MillionSongSubset/data/B/B/D/TRBBDSZ128F4273088.h5
# /home/ubuntu/MillionSongSubset/data/B/B/D/TRBBDZF128F424BE45.h5
# /home/ubuntu/MillionSongSubset/data/B/B/K/TRBBKUZ128F92C9D49.h5
# /home/ubuntu/MillionSongSubset/data/B/B/K/TRBBKMZ128F93539F4.h5
# /home/ubuntu/MillionSongSubset/data/B/B/K/TRBBKTZ128F1456D67.h5
# /home/ubuntu/MillionSongSubset/data/B/B/K/TRBBKAI128F4251AEF.h5
# /home/ubuntu/MillionSongSubset/data/B/B/K/TRBBKAJ128F92D6072.h5
# /home/ubuntu/MillionSongSubset/data/B/B/K/TRBBKIH128F9343FD4.h5
# /home/ubuntu/MillionSongSubset/data/B/B/K/TRBBKXZ128F4215C88.h5
# /home/ubuntu/MillionSongSubset/data/B/B/K/TRBBKLD128F424ABF5.h5
# /home/ubuntu/MillionSongSubset/data/B/B/K/TRBBKTG128E0785461.h5
# /home/ubuntu/MillionSongSubset/data/B/B/Z/TRBBZJP128F4287992.h5
# /home/ubuntu/MillionSongSubset/data/B/B/Z/TRBBZAE128F92FDC05.h5
# /home/ubuntu/MillionSongSubset/data/B/B/Z/TRBBZOG128F422B02B.h5
# /home/ubuntu/MillionSongSubset/data/B/B/Z/TRBBZXJ12903CD3E8D.h5
# /home/ubuntu/MillionSongSubset/data/B/B/Z/TRBBZFO128F932CD27.h5
# /home/ubuntu/MillionSongSubset/data/B/B/Z/TRBBZJW12903CF71A6.h5
# /home/ubuntu/MillionSongSubset/data/B/B/Z/TRBBZRF128F9321407.h5
# /home/ubuntu/MillionSongSubset/data/B/B/Z/TRBBZCM12903CDDDA5.h5
# /home/ubuntu/MillionSongSubset/data/B/B/Z/TRBBZSO128F4257B30.h5
# /home/ubuntu/MillionSongSubset/data/B/B/Z/TRBBZWC128F93172DA.h5
# /home/ubuntu/MillionSongSubset/data/B/B/Z/TRBBZQM128F931A529.h5
# /home/ubuntu/MillionSongSubset/data/B/B/Z/TRBBZTM12903CB84F3.h5
# /home/ubuntu/MillionSongSubset/data/B/B/H/TRBBHWG128F4249F32.h5
# /home/ubuntu/MillionSongSubset/data/B/B/H/TRBBHQO128F9341FC8.h5
# /home/ubuntu/MillionSongSubset/data/B/B/H/TRBBHPQ128F145A7F8.h5
# /home/ubuntu/MillionSongSubset/data/B/B/H/TRBBHUR128F92FDBE2.h5
# /home/ubuntu/MillionSongSubset/data/B/B/H/TRBBHUW128F429476F.h5
# /home/ubuntu/MillionSongSubset/data/B/B/H/TRBBHZV128F429A392.h5
# /home/ubuntu/MillionSongSubset/data/B/B/H/TRBBHLO128F9302EA4.h5
# /home/ubuntu/MillionSongSubset/data/B/B/H/TRBBHFE12903CA5EEB.h5
# /home/ubuntu/MillionSongSubset/data/B/B/H/TRBBHQJ128F92CC610.h5
# /home/ubuntu/MillionSongSubset/data/B/B/H/TRBBHHP128EF365DA0.h5
# /home/ubuntu/MillionSongSubset/data/B/B/M/TRBBMAM128F4290E48.h5
# /home/ubuntu/MillionSongSubset/data/B/B/M/TRBBMAL128F146B288.h5
# /home/ubuntu/MillionSongSubset/data/B/B/M/TRBBMDA12903CB688E.h5
# /home/ubuntu/MillionSongSubset/data/B/B/M/TRBBMVE128F92DA833.h5
# /home/ubuntu/MillionSongSubset/data/B/B/M/TRBBMXP128F9325219.h5
# /home/ubuntu/MillionSongSubset/data/B/B/M/TRBBMTJ128F1477785.h5
# /home/ubuntu/MillionSongSubset/data/B/B/M/TRBBMTZ128F4260C61.h5
# /home/ubuntu/MillionSongSubset/data/B/B/M/TRBBMYD12903CC2638.h5
# /home/ubuntu/MillionSongSubset/data/B/B/M/TRBBMIR128F933DF44.h5
# /home/ubuntu/MillionSongSubset/data/B/B/M/TRBBMPH128F1469775.h5
# /home/ubuntu/MillionSongSubset/data/B/B/M/TRBBMHE128EF341D09.h5
# /home/ubuntu/MillionSongSubset/data/B/B/M/TRBBMLR128F1466822.h5
# /home/ubuntu/MillionSongSubset/data/B/B/M/TRBBMIF12903CA1EB0.h5
# /home/ubuntu/MillionSongSubset/data/B/B/M/TRBBMXI128F428CCD1.h5
# /home/ubuntu/MillionSongSubset/data/B/B/M/TRBBMQN128EF35F995.h5
# /home/ubuntu/MillionSongSubset/data/B/B/M/TRBBMQO128F425559F.h5
# /home/ubuntu/MillionSongSubset/data/B/B/O/TRBBOTI12903CD9CBB.h5
# /home/ubuntu/MillionSongSubset/data/B/B/O/TRBBOBQ12903CC5186.h5
# /home/ubuntu/MillionSongSubset/data/B/B/O/TRBBOBO128F425FDFC.h5
# /home/ubuntu/MillionSongSubset/data/B/B/O/TRBBOUN128F425A4E6.h5
# /home/ubuntu/MillionSongSubset/data/B/B/O/TRBBOFH128F14A2A46.h5
# /home/ubuntu/MillionSongSubset/data/B/B/O/TRBBOME12903CC3862.h5
# /home/ubuntu/MillionSongSubset/data/B/B/O/TRBBOPV12903CFB50F.h5
# /home/ubuntu/MillionSongSubset/data/B/B/O/TRBBOUO128F92D246B.h5
# /home/ubuntu/MillionSongSubset/data/B/B/O/TRBBOPX12903D106F7.h5
# /home/ubuntu/MillionSongSubset/data/B/B/O/TRBBOJM12903CD1BDD.h5
# /home/ubuntu/MillionSongSubset/data/B/B/O/TRBBOKQ128F933AE7C.h5
# /home/ubuntu/MillionSongSubset/data/B/B/X/TRBBXXC128F427044F.h5
# /home/ubuntu/MillionSongSubset/data/B/B/X/TRBBXWG128F148B444.h5
# /home/ubuntu/MillionSongSubset/data/B/B/X/TRBBXPL128F9321D39.h5
# /home/ubuntu/MillionSongSubset/data/B/B/X/TRBBXLI128F931BC58.h5
# /home/ubuntu/MillionSongSubset/data/B/B/X/TRBBXML128F4256DFF.h5
# /home/ubuntu/MillionSongSubset/data/B/B/X/TRBBXTY128F427EA62.h5
# /home/ubuntu/MillionSongSubset/data/B/B/X/TRBBXGU12903CCC870.h5
# /home/ubuntu/MillionSongSubset/data/B/B/X/TRBBXLS128F9323D9B.h5
# /home/ubuntu/MillionSongSubset/data/B/B/X/TRBBXEG128F424EC2C.h5
# /home/ubuntu/MillionSongSubset/data/B/B/X/TRBBXMC128F422C330.h5
# /home/ubuntu/MillionSongSubset/data/B/B/X/TRBBXSE128F42798F6.h5
# /home/ubuntu/MillionSongSubset/data/B/B/X/TRBBXWQ128F93418EB.h5
# /home/ubuntu/MillionSongSubset/data/B/B/G/TRBBGMS128F424C656.h5
# /home/ubuntu/MillionSongSubset/data/B/B/G/TRBBGDK128F427D450.h5
# /home/ubuntu/MillionSongSubset/data/B/B/G/TRBBGUV128F92DFA21.h5
# /home/ubuntu/MillionSongSubset/data/B/B/G/TRBBGQN128F9310CBE.h5
# /home/ubuntu/MillionSongSubset/data/B/B/G/TRBBGMX128F932B156.h5
# /home/ubuntu/MillionSongSubset/data/B/B/G/TRBBGEG128F425CEDD.h5
# /home/ubuntu/MillionSongSubset/data/B/B/G/TRBBGFR128F427B5BD.h5
# /home/ubuntu/MillionSongSubset/data/B/B/G/TRBBGOG128EF33EDCA.h5
# /home/ubuntu/MillionSongSubset/data/B/B/G/TRBBGMD128F4229F92.h5
# /home/ubuntu/MillionSongSubset/data/B/B/W/TRBBWCP128F935F6DB.h5
# /home/ubuntu/MillionSongSubset/data/B/B/W/TRBBWKF128F934E709.h5
# /home/ubuntu/MillionSongSubset/data/B/B/W/TRBBWNS128F426F760.h5
# /home/ubuntu/MillionSongSubset/data/B/B/W/TRBBWIP128F4287400.h5
# /home/ubuntu/MillionSongSubset/data/B/B/W/TRBBWDJ128F42595D5.h5
# /home/ubuntu/MillionSongSubset/data/B/B/W/TRBBWKS128F424E84A.h5
# /home/ubuntu/MillionSongSubset/data/B/B/W/TRBBWSE128F9313963.h5
# /home/ubuntu/MillionSongSubset/data/B/B/A/TRBBAAD128F42B0C9D.h5
# /home/ubuntu/MillionSongSubset/data/B/B/A/TRBBACZ128F9339B90.h5
# /home/ubuntu/MillionSongSubset/data/B/B/A/TRBBAKH128F92FA339.h5
# /home/ubuntu/MillionSongSubset/data/B/B/A/TRBBARP128F9306CBE.h5
# /home/ubuntu/MillionSongSubset/data/B/B/A/TRBBALB12903CAC0B5.h5
# /home/ubuntu/MillionSongSubset/data/B/B/A/TRBBANU128F422B87B.h5
# /home/ubuntu/MillionSongSubset/data/B/B/A/TRBBADO12903CEE832.h5
# /home/ubuntu/MillionSongSubset/data/B/B/A/TRBBAHD128F428E0FE.h5
# /home/ubuntu/MillionSongSubset/data/B/B/A/TRBBANR128F4277C5B.h5
# /home/ubuntu/MillionSongSubset/data/B/B/A/TRBBASV128F427680E.h5
# /home/ubuntu/MillionSongSubset/data/B/B/A/TRBBAQJ128F92F1336.h5
# /home/ubuntu/MillionSongSubset/data/B/B/A/TRBBAAZ12903CAEA6D.h5
# /home/ubuntu/MillionSongSubset/data/B/B/A/TRBBADQ128F933698F.h5
# /home/ubuntu/MillionSongSubset/data/B/B/A/TRBBAIC12903D11771.h5
# /home/ubuntu/MillionSongSubset/data/B/B/A/TRBBAKQ128F92F0A8E.h5
# /home/ubuntu/MillionSongSubset/data/B/E/T/TRBETHV128F429722F.h5
# /home/ubuntu/MillionSongSubset/data/B/E/T/TRBETVK128F4288B49.h5
# /home/ubuntu/MillionSongSubset/data/B/E/T/TRBETSW12903CA6A6B.h5
# /home/ubuntu/MillionSongSubset/data/B/E/T/TRBETRA128F9327DC6.h5
# /home/ubuntu/MillionSongSubset/data/B/E/S/TRBESXG128F4243BFB.h5
# /home/ubuntu/MillionSongSubset/data/B/E/S/TRBESAQ12903CD9497.h5
# /home/ubuntu/MillionSongSubset/data/B/E/S/TRBESEX128F147BB13.h5
# /home/ubuntu/MillionSongSubset/data/B/E/S/TRBESWC128EF34B859.h5
# /home/ubuntu/MillionSongSubset/data/B/E/S/TRBESDU128F92F3CE9.h5
# /home/ubuntu/MillionSongSubset/data/B/E/S/TRBESBZ12903CA0A95.h5
# /home/ubuntu/MillionSongSubset/data/B/E/S/TRBESVW128F92F6960.h5
# /home/ubuntu/MillionSongSubset/data/B/E/S/TRBESDU128F4277813.h5
# /home/ubuntu/MillionSongSubset/data/B/E/S/TRBESGH128E0788912.h5
# /home/ubuntu/MillionSongSubset/data/B/E/S/TRBESWH128F14722F5.h5
# /home/ubuntu/MillionSongSubset/data/B/E/B/TRBEBTR128F932CD6B.h5
# /home/ubuntu/MillionSongSubset/data/B/E/B/TRBEBNV128F423783D.h5
# /home/ubuntu/MillionSongSubset/data/B/E/B/TRBEBWG128F93214A4.h5
# /home/ubuntu/MillionSongSubset/data/B/E/B/TRBEBWN128F933D21F.h5
# /home/ubuntu/MillionSongSubset/data/B/E/B/TRBEBAS128F92EAC23.h5
# /home/ubuntu/MillionSongSubset/data/B/E/B/TRBEBVZ128F425A660.h5
# /home/ubuntu/MillionSongSubset/data/B/E/B/TRBEBEZ128E0792F08.h5
# /home/ubuntu/MillionSongSubset/data/B/E/B/TRBEBFU128F14971BD.h5
# /home/ubuntu/MillionSongSubset/data/B/E/B/TRBEBUU128F92C945D.h5
# /home/ubuntu/MillionSongSubset/data/B/E/B/TRBEBYV128F14A0B65.h5
# /home/ubuntu/MillionSongSubset/data/B/E/J/TRBEJFD128F93222D8.h5
# /home/ubuntu/MillionSongSubset/data/B/E/J/TRBEJYW128F93018AF.h5
# /home/ubuntu/MillionSongSubset/data/B/E/J/TRBEJHQ128F421EFD2.h5
# /home/ubuntu/MillionSongSubset/data/B/E/J/TRBEJVP128F429D21B.h5
# /home/ubuntu/MillionSongSubset/data/B/E/J/TRBEJKS128F426D823.h5
# /home/ubuntu/MillionSongSubset/data/B/E/J/TRBEJHM12903CBE801.h5
# /home/ubuntu/MillionSongSubset/data/B/E/J/TRBEJCS128F4249EA2.h5
# /home/ubuntu/MillionSongSubset/data/B/E/J/TRBEJDZ128F92D02F8.h5
# /home/ubuntu/MillionSongSubset/data/B/E/J/TRBEJKW128F92FCEED.h5
# /home/ubuntu/MillionSongSubset/data/B/E/E/TRBEEMB128F9320082.h5
# /home/ubuntu/MillionSongSubset/data/B/E/E/TRBEEQG128F42732AB.h5
# /home/ubuntu/MillionSongSubset/data/B/E/E/TRBEEEP128F426C17D.h5
# /home/ubuntu/MillionSongSubset/data/B/E/E/TRBEEWS12903CD0B60.h5
# /home/ubuntu/MillionSongSubset/data/B/E/E/TRBEEAF128F92E6382.h5
# /home/ubuntu/MillionSongSubset/data/B/E/E/TRBEEQF128F4283395.h5
# /home/ubuntu/MillionSongSubset/data/B/E/E/TRBEELS128F42B63A8.h5
# /home/ubuntu/MillionSongSubset/data/B/E/E/TRBEEDK128F424D995.h5
# /home/ubuntu/MillionSongSubset/data/B/E/E/TRBEERY128F4231A2E.h5
# /home/ubuntu/MillionSongSubset/data/B/E/E/TRBEEWC128F9344A22.h5
# /home/ubuntu/MillionSongSubset/data/B/E/E/TRBEEJS128F9340A8B.h5
# /home/ubuntu/MillionSongSubset/data/B/E/E/TRBEEJH128F92FAC0D.h5
# /home/ubuntu/MillionSongSubset/data/B/E/N/TRBENOX128F4243501.h5
# /home/ubuntu/MillionSongSubset/data/B/E/N/TRBENZB128F429C5FD.h5
# /home/ubuntu/MillionSongSubset/data/B/E/N/TRBENBG12903CF94B4.h5
# /home/ubuntu/MillionSongSubset/data/B/E/N/TRBENIG128F92F281E.h5
# /home/ubuntu/MillionSongSubset/data/B/E/N/TRBENNA12903D0411A.h5
# /home/ubuntu/MillionSongSubset/data/B/E/N/TRBENCK128F4232BB2.h5
# /home/ubuntu/MillionSongSubset/data/B/E/N/TRBENZL128F1455ECA.h5
# /home/ubuntu/MillionSongSubset/data/B/E/N/TRBENDH128F1467D62.h5
# /home/ubuntu/MillionSongSubset/data/B/E/N/TRBENWE128F424AE09.h5
# /home/ubuntu/MillionSongSubset/data/B/E/N/TRBENTT128E0781C26.h5
# /home/ubuntu/MillionSongSubset/data/B/E/N/TRBENHU12903CB6830.h5
# /home/ubuntu/MillionSongSubset/data/B/E/N/TRBENZA12903CBF40F.h5
# /home/ubuntu/MillionSongSubset/data/B/E/I/TRBEIBI12903CBD2B6.h5
# /home/ubuntu/MillionSongSubset/data/B/E/I/TRBEIKX12903CCAAE5.h5
# /home/ubuntu/MillionSongSubset/data/B/E/I/TRBEIAM12903CF4476.h5
# /home/ubuntu/MillionSongSubset/data/B/E/I/TRBEISX128F9322F51.h5
# /home/ubuntu/MillionSongSubset/data/B/E/I/TRBEIRT128F42A6680.h5
# /home/ubuntu/MillionSongSubset/data/B/E/I/TRBEIKK128F14628D6.h5
# /home/ubuntu/MillionSongSubset/data/B/E/I/TRBEIBI12903CC4C7B.h5
# /home/ubuntu/MillionSongSubset/data/B/E/I/TRBEIVC128F9320E95.h5
# /home/ubuntu/MillionSongSubset/data/B/E/I/TRBEISL128F931B107.h5
# /home/ubuntu/MillionSongSubset/data/B/E/I/TRBEIYU128F92E88A9.h5
# /home/ubuntu/MillionSongSubset/data/B/E/C/TRBECMV128F427614B.h5
# /home/ubuntu/MillionSongSubset/data/B/E/C/TRBECNW128F426BE82.h5
# /home/ubuntu/MillionSongSubset/data/B/E/C/TRBECBY128F148B6F3.h5
# /home/ubuntu/MillionSongSubset/data/B/E/C/TRBECUJ128F14B0BA7.h5
# /home/ubuntu/MillionSongSubset/data/B/E/C/TRBECNX128F92FA80F.h5
# /home/ubuntu/MillionSongSubset/data/B/E/C/TRBECBM128F426AA34.h5
# /home/ubuntu/MillionSongSubset/data/B/E/C/TRBECAL128F4270F27.h5
# /home/ubuntu/MillionSongSubset/data/B/E/C/TRBECKU128F428B08A.h5
# /home/ubuntu/MillionSongSubset/data/B/E/C/TRBECVD128F92F9E21.h5
# /home/ubuntu/MillionSongSubset/data/B/E/C/TRBECDN128F4225717.h5
# /home/ubuntu/MillionSongSubset/data/B/E/C/TRBECST12903CDC40B.h5
# /home/ubuntu/MillionSongSubset/data/B/E/C/TRBECIP128F42515B1.h5
# /home/ubuntu/MillionSongSubset/data/B/E/C/TRBECGH12903CC2304.h5
# /home/ubuntu/MillionSongSubset/data/B/E/C/TRBECRX128F423B50B.h5
# /home/ubuntu/MillionSongSubset/data/B/E/P/TRBEPQG128F42547F6.h5
# /home/ubuntu/MillionSongSubset/data/B/E/P/TRBEPAA128F4263E2E.h5
# /home/ubuntu/MillionSongSubset/data/B/E/P/TRBEPAL128F932C21B.h5
# /home/ubuntu/MillionSongSubset/data/B/E/P/TRBEPTD12903CDFD52.h5
# /home/ubuntu/MillionSongSubset/data/B/E/P/TRBEPKI128F9353F14.h5
# /home/ubuntu/MillionSongSubset/data/B/E/P/TRBEPWY12903CB1CBE.h5
# /home/ubuntu/MillionSongSubset/data/B/E/P/TRBEPTI128F4266340.h5
# /home/ubuntu/MillionSongSubset/data/B/E/P/TRBEPVA128F932C6FE.h5
# /home/ubuntu/MillionSongSubset/data/B/E/P/TRBEPMK128F92D61AE.h5
# /home/ubuntu/MillionSongSubset/data/B/E/L/TRBELYI128F147E20B.h5
# /home/ubuntu/MillionSongSubset/data/B/E/L/TRBELVP128F93263B8.h5
# /home/ubuntu/MillionSongSubset/data/B/E/L/TRBELXO128F427CAFA.h5
# /home/ubuntu/MillionSongSubset/data/B/E/L/TRBELUA12903CB0371.h5
# /home/ubuntu/MillionSongSubset/data/B/E/L/TRBELAZ128F422B87F.h5
# /home/ubuntu/MillionSongSubset/data/B/E/L/TRBELDP128F427EDD0.h5
# /home/ubuntu/MillionSongSubset/data/B/E/L/TRBELIO128F428F322.h5
# /home/ubuntu/MillionSongSubset/data/B/E/U/TRBEUMG128F422305C.h5
# /home/ubuntu/MillionSongSubset/data/B/E/U/TRBEUOY128F932B2D7.h5
# /home/ubuntu/MillionSongSubset/data/B/E/U/TRBEUDN128F14860CE.h5
# /home/ubuntu/MillionSongSubset/data/B/E/U/TRBEUQH128F93152E8.h5
# /home/ubuntu/MillionSongSubset/data/B/E/U/TRBEUVP128F427831E.h5
# /home/ubuntu/MillionSongSubset/data/B/E/U/TRBEUSV128F42A5F43.h5
# /home/ubuntu/MillionSongSubset/data/B/E/U/TRBEUWA12903CB5CDE.h5
# /home/ubuntu/MillionSongSubset/data/B/E/U/TRBEUKI128F9318306.h5
# /home/ubuntu/MillionSongSubset/data/B/E/Q/TRBEQHL128F4272CBC.h5
# /home/ubuntu/MillionSongSubset/data/B/E/Q/TRBEQNH12903CB087E.h5
# /home/ubuntu/MillionSongSubset/data/B/E/Q/TRBEQPB128F933D621.h5
# /home/ubuntu/MillionSongSubset/data/B/E/Q/TRBEQZJ128F9300B50.h5
# /home/ubuntu/MillionSongSubset/data/B/E/Q/TRBEQFT128F146BD6D.h5
# /home/ubuntu/MillionSongSubset/data/B/E/Q/TRBEQUV12903CBD17A.h5
# /home/ubuntu/MillionSongSubset/data/B/E/Q/TRBEQFT128F4238A28.h5
# /home/ubuntu/MillionSongSubset/data/B/E/Q/TRBEQNB128F9327242.h5
# /home/ubuntu/MillionSongSubset/data/B/E/F/TRBEFDI12903CCF154.h5
# /home/ubuntu/MillionSongSubset/data/B/E/F/TRBEFQB128F932138A.h5
# /home/ubuntu/MillionSongSubset/data/B/E/F/TRBEFKV128F930114A.h5
# /home/ubuntu/MillionSongSubset/data/B/E/F/TRBEFAS128F4262569.h5
# /home/ubuntu/MillionSongSubset/data/B/E/F/TRBEFUY12903C98485.h5
# /home/ubuntu/MillionSongSubset/data/B/E/F/TRBEFWM128F428EFA8.h5
# /home/ubuntu/MillionSongSubset/data/B/E/F/TRBEFQY128F932EE3F.h5
# /home/ubuntu/MillionSongSubset/data/B/E/F/TRBEFFA128F930F017.h5
# /home/ubuntu/MillionSongSubset/data/B/E/F/TRBEFFG128E0793C24.h5
# /home/ubuntu/MillionSongSubset/data/B/E/F/TRBEFJE128F932139E.h5
# /home/ubuntu/MillionSongSubset/data/B/E/V/TRBEVII12903CA1A06.h5
# /home/ubuntu/MillionSongSubset/data/B/E/V/TRBEVTM128F92FE2B2.h5
# /home/ubuntu/MillionSongSubset/data/B/E/V/TRBEVJC12903CCE75B.h5
# /home/ubuntu/MillionSongSubset/data/B/E/V/TRBEVND128F93429DD.h5
# /home/ubuntu/MillionSongSubset/data/B/E/V/TRBEVZN128F9330A0D.h5
# /home/ubuntu/MillionSongSubset/data/B/E/V/TRBEVSH128F92D5CFC.h5
# /home/ubuntu/MillionSongSubset/data/B/E/R/TRBEROX128F4270745.h5
# /home/ubuntu/MillionSongSubset/data/B/E/R/TRBERKY128F42290CA.h5
# /home/ubuntu/MillionSongSubset/data/B/E/R/TRBERHG128F933AC46.h5
# /home/ubuntu/MillionSongSubset/data/B/E/R/TRBERUM128F148AC93.h5
# /home/ubuntu/MillionSongSubset/data/B/E/R/TRBERCZ128E0787D93.h5
# /home/ubuntu/MillionSongSubset/data/B/E/R/TRBERLZ12903CC4747.h5
# /home/ubuntu/MillionSongSubset/data/B/E/R/TRBERHS128F92FF079.h5
# /home/ubuntu/MillionSongSubset/data/B/E/R/TRBERGT128F42A009F.h5
# /home/ubuntu/MillionSongSubset/data/B/E/R/TRBERJE128F425F098.h5
# /home/ubuntu/MillionSongSubset/data/B/E/R/TRBERIX12903CEF907.h5
# /home/ubuntu/MillionSongSubset/data/B/E/R/TRBERJV128F1458463.h5
# /home/ubuntu/MillionSongSubset/data/B/E/Y/TRBEYOL128F4222488.h5
# /home/ubuntu/MillionSongSubset/data/B/E/Y/TRBEYIB12903CD273F.h5
# /home/ubuntu/MillionSongSubset/data/B/E/Y/TRBEYXK128F427E125.h5
# /home/ubuntu/MillionSongSubset/data/B/E/Y/TRBEYAK128F9334433.h5
# /home/ubuntu/MillionSongSubset/data/B/E/Y/TRBEYTH128F9309622.h5
# /home/ubuntu/MillionSongSubset/data/B/E/Y/TRBEYJR128F4292651.h5
# /home/ubuntu/MillionSongSubset/data/B/E/Y/TRBEYFC128F4286D0A.h5
# /home/ubuntu/MillionSongSubset/data/B/E/Y/TRBEYPA128F933197C.h5
# /home/ubuntu/MillionSongSubset/data/B/E/Y/TRBEYDS128F148C563.h5
# /home/ubuntu/MillionSongSubset/data/B/E/Y/TRBEYEO128F9308A8D.h5
# /home/ubuntu/MillionSongSubset/data/B/E/Y/TRBEYVD12903CE3DE9.h5
# /home/ubuntu/MillionSongSubset/data/B/E/Y/TRBEYLQ128F42AA7AF.h5
# /home/ubuntu/MillionSongSubset/data/B/E/Y/TRBEYYM128F1493C56.h5
# /home/ubuntu/MillionSongSubset/data/B/E/Y/TRBEYYO12903D0DBB1.h5
# /home/ubuntu/MillionSongSubset/data/B/E/Y/TRBEYTT12903CA0A8E.h5
# /home/ubuntu/MillionSongSubset/data/B/E/Y/TRBEYPF128F92EA5E8.h5
# /home/ubuntu/MillionSongSubset/data/B/E/D/TRBEDLE128F933039C.h5
# /home/ubuntu/MillionSongSubset/data/B/E/D/TRBEDHB12903CDB820.h5
# /home/ubuntu/MillionSongSubset/data/B/E/D/TRBEDXK128F14A7EC0.h5
# /home/ubuntu/MillionSongSubset/data/B/E/D/TRBEDBC128F145B134.h5
# /home/ubuntu/MillionSongSubset/data/B/E/D/TRBEDTM128F4255119.h5
# /home/ubuntu/MillionSongSubset/data/B/E/D/TRBEDZL128F425A2E7.h5
# /home/ubuntu/MillionSongSubset/data/B/E/D/TRBEDIR128F4250FBD.h5
# /home/ubuntu/MillionSongSubset/data/B/E/D/TRBEDRW128F425F424.h5
# /home/ubuntu/MillionSongSubset/data/B/E/D/TRBEDVH128F14599C7.h5
# /home/ubuntu/MillionSongSubset/data/B/E/K/TRBEKJN128F42891EE.h5
# /home/ubuntu/MillionSongSubset/data/B/E/K/TRBEKMX128F92D7B75.h5
# /home/ubuntu/MillionSongSubset/data/B/E/K/TRBEKDE128F92E7486.h5
# /home/ubuntu/MillionSongSubset/data/B/E/K/TRBEKNV128F9326A8A.h5
# /home/ubuntu/MillionSongSubset/data/B/E/K/TRBEKLP128F92FB2BD.h5
# /home/ubuntu/MillionSongSubset/data/B/E/K/TRBEKGF12903CBE1C6.h5
# /home/ubuntu/MillionSongSubset/data/B/E/K/TRBEKGR128F425DA44.h5
# /home/ubuntu/MillionSongSubset/data/B/E/Z/TRBEZOR128F14A4E31.h5
# /home/ubuntu/MillionSongSubset/data/B/E/Z/TRBEZGW128F9337413.h5
# /home/ubuntu/MillionSongSubset/data/B/E/Z/TRBEZEM128F92F135A.h5
# /home/ubuntu/MillionSongSubset/data/B/E/Z/TRBEZYJ12903CAC89F.h5
# /home/ubuntu/MillionSongSubset/data/B/E/Z/TRBEZHU128F9306C1C.h5
# /home/ubuntu/MillionSongSubset/data/B/E/Z/TRBEZEL128E079116D.h5
# /home/ubuntu/MillionSongSubset/data/B/E/Z/TRBEZBD128F92CE0EE.h5
# /home/ubuntu/MillionSongSubset/data/B/E/Z/TRBEZTX128F4271207.h5
# /home/ubuntu/MillionSongSubset/data/B/E/Z/TRBEZUP128F9331747.h5
# /home/ubuntu/MillionSongSubset/data/B/E/Z/TRBEZQO128F4287E04.h5
# /home/ubuntu/MillionSongSubset/data/B/E/Z/TRBEZFS128F92E40DD.h5
# /home/ubuntu/MillionSongSubset/data/B/E/Z/TRBEZEI12903CA7445.h5
# /home/ubuntu/MillionSongSubset/data/B/E/H/TRBEHNT128E0792546.h5
# /home/ubuntu/MillionSongSubset/data/B/E/H/TRBEHGH128E078DEDE.h5
# /home/ubuntu/MillionSongSubset/data/B/E/H/TRBEHVM128F93506BD.h5
# /home/ubuntu/MillionSongSubset/data/B/E/H/TRBEHDI128F930D7C2.h5
# /home/ubuntu/MillionSongSubset/data/B/E/H/TRBEHTC128F42150EB.h5
# /home/ubuntu/MillionSongSubset/data/B/E/H/TRBEHKV128F92F93DF.h5
# /home/ubuntu/MillionSongSubset/data/B/E/H/TRBEHBS128F4233471.h5
# /home/ubuntu/MillionSongSubset/data/B/E/H/TRBEHHL128F92E90F5.h5
# /home/ubuntu/MillionSongSubset/data/B/E/H/TRBEHEY128F92C2852.h5
# /home/ubuntu/MillionSongSubset/data/B/E/H/TRBEHHY12903CF3AE8.h5
# /home/ubuntu/MillionSongSubset/data/B/E/H/TRBEHFA128F145B3DA.h5
# /home/ubuntu/MillionSongSubset/data/B/E/H/TRBEHAS128F933A549.h5
# /home/ubuntu/MillionSongSubset/data/B/E/M/TRBEMJC128F14A6E0D.h5
# /home/ubuntu/MillionSongSubset/data/B/E/M/TRBEMDL128F424ABD6.h5
# /home/ubuntu/MillionSongSubset/data/B/E/M/TRBEMRD128F426DEC7.h5
# /home/ubuntu/MillionSongSubset/data/B/E/M/TRBEMMZ128F145C514.h5
# /home/ubuntu/MillionSongSubset/data/B/E/M/TRBEMBM128F9324F2B.h5
# /home/ubuntu/MillionSongSubset/data/B/E/M/TRBEMTB128F14ACBDF.h5
# /home/ubuntu/MillionSongSubset/data/B/E/M/TRBEMAH128F424215B.h5
# /home/ubuntu/MillionSongSubset/data/B/E/M/TRBEMTF128F42660CA.h5
# /home/ubuntu/MillionSongSubset/data/B/E/O/TRBEOUP12903CF652E.h5
# /home/ubuntu/MillionSongSubset/data/B/E/O/TRBEONB128EF3405E6.h5
# /home/ubuntu/MillionSongSubset/data/B/E/O/TRBEORW128F42A3A56.h5
# /home/ubuntu/MillionSongSubset/data/B/E/O/TRBEOMZ12903CBCD33.h5
# /home/ubuntu/MillionSongSubset/data/B/E/O/TRBEOUT12903CD5981.h5
# /home/ubuntu/MillionSongSubset/data/B/E/O/TRBEOIU128F4296D36.h5
# /home/ubuntu/MillionSongSubset/data/B/E/O/TRBEOSC128F426AB23.h5
# /home/ubuntu/MillionSongSubset/data/B/E/O/TRBEOYQ128F42955C3.h5
# /home/ubuntu/MillionSongSubset/data/B/E/O/TRBEONX128E0788D2B.h5
# /home/ubuntu/MillionSongSubset/data/B/E/O/TRBEOOD128E0795C84.h5
# /home/ubuntu/MillionSongSubset/data/B/E/O/TRBEOCF128F426BFDC.h5
# /home/ubuntu/MillionSongSubset/data/B/E/O/TRBEORE128F92E8476.h5
# /home/ubuntu/MillionSongSubset/data/B/E/O/TRBEODT128F424AE26.h5
# /home/ubuntu/MillionSongSubset/data/B/E/X/TRBEXIO128F9300E56.h5
# /home/ubuntu/MillionSongSubset/data/B/E/X/TRBEXHU128F93390C5.h5
# /home/ubuntu/MillionSongSubset/data/B/E/X/TRBEXHF128F4266092.h5
# /home/ubuntu/MillionSongSubset/data/B/E/X/TRBEXRS128F4269FAA.h5
# /home/ubuntu/MillionSongSubset/data/B/E/X/TRBEXNJ128F92F6DD6.h5
# /home/ubuntu/MillionSongSubset/data/B/E/X/TRBEXJN128F42B18D6.h5
# /home/ubuntu/MillionSongSubset/data/B/E/X/TRBEXUF128F92DF175.h5
# /home/ubuntu/MillionSongSubset/data/B/E/X/TRBEXRY128F14661D0.h5
# /home/ubuntu/MillionSongSubset/data/B/E/X/TRBEXPZ128F42302F2.h5
# /home/ubuntu/MillionSongSubset/data/B/E/G/TRBEGQC12903CAB228.h5
# /home/ubuntu/MillionSongSubset/data/B/E/G/TRBEGMU128F9325473.h5
# /home/ubuntu/MillionSongSubset/data/B/E/G/TRBEGMG128F92FD7C4.h5
# /home/ubuntu/MillionSongSubset/data/B/E/G/TRBEGKI12903CBD34C.h5
# /home/ubuntu/MillionSongSubset/data/B/E/G/TRBEGAV12903D16172.h5
# /home/ubuntu/MillionSongSubset/data/B/E/G/TRBEGWL128F423F4F1.h5
# /home/ubuntu/MillionSongSubset/data/B/E/G/TRBEGHL128F92F76E8.h5
# /home/ubuntu/MillionSongSubset/data/B/E/G/TRBEGJR128F4275E2E.h5
# /home/ubuntu/MillionSongSubset/data/B/E/W/TRBEWCS128F428BA34.h5
# /home/ubuntu/MillionSongSubset/data/B/E/W/TRBEWHE128F425E528.h5
# /home/ubuntu/MillionSongSubset/data/B/E/W/TRBEWTR12903CBF252.h5
# /home/ubuntu/MillionSongSubset/data/B/E/W/TRBEWTY12903CB4779.h5
# /home/ubuntu/MillionSongSubset/data/B/E/A/TRBEAMO128F425B75F.h5
# /home/ubuntu/MillionSongSubset/data/B/E/A/TRBEAZN128F14858B3.h5
# /home/ubuntu/MillionSongSubset/data/B/E/A/TRBEAXZ128F424347B.h5
# /home/ubuntu/MillionSongSubset/data/B/E/A/TRBEAWP128F422B4D1.h5
# /home/ubuntu/MillionSongSubset/data/B/E/A/TRBEACH128EF341C45.h5
# /home/ubuntu/MillionSongSubset/data/B/E/A/TRBEAOU128E0798350.h5
# /home/ubuntu/MillionSongSubset/data/B/E/A/TRBEARH128F422A535.h5
# /home/ubuntu/MillionSongSubset/data/B/E/A/TRBEATE128E078F0D8.h5
# /home/ubuntu/MillionSongSubset/data/B/E/A/TRBEATF128F9309E63.h5
# /home/ubuntu/MillionSongSubset/data/B/E/A/TRBEAJB128F4214A06.h5
# /home/ubuntu/MillionSongSubset/data/B/E/A/TRBEADA128F1455D45.h5
# /home/ubuntu/MillionSongSubset/data/B/E/A/TRBEAXM12903CC63F5.h5
# /home/ubuntu/MillionSongSubset/data/B/E/A/TRBEAYH12903CBC75F.h5
# /home/ubuntu/MillionSongSubset/data/B/I/B/TRBIBGN128F42ADC66.h5
# /home/ubuntu/MillionSongSubset/data/B/I/B/TRBIBSS128F14A205E.h5
# /home/ubuntu/MillionSongSubset/data/B/I/B/TRBIBLK128F4264240.h5
# /home/ubuntu/MillionSongSubset/data/B/I/B/TRBIBKU128F422A0E3.h5
# /home/ubuntu/MillionSongSubset/data/B/I/B/TRBIBLJ12903CCF436.h5
# /home/ubuntu/MillionSongSubset/data/B/I/B/TRBIBAQ128F93279F5.h5
# /home/ubuntu/MillionSongSubset/data/B/I/B/TRBIBFY128F932C0E3.h5
# /home/ubuntu/MillionSongSubset/data/B/I/B/TRBIBTE128E078E882.h5
# /home/ubuntu/MillionSongSubset/data/B/I/B/TRBIBSN128F92FBA64.h5
# /home/ubuntu/MillionSongSubset/data/B/I/B/TRBIBTU128F92FDC9D.h5
# /home/ubuntu/MillionSongSubset/data/B/I/B/TRBIBSK128F92E5624.h5
# /home/ubuntu/MillionSongSubset/data/B/I/B/TRBIBVM128F4262E9D.h5
# /home/ubuntu/MillionSongSubset/data/B/I/B/TRBIBKA128F42947BF.h5
# /home/ubuntu/MillionSongSubset/data/B/I/B/TRBIBOJ128F14618D4.h5
# /home/ubuntu/MillionSongSubset/data/B/I/J/TRBIJLT12903CE7070.h5
# /home/ubuntu/MillionSongSubset/data/B/I/J/TRBIJRN128F425F3DD.h5
# /home/ubuntu/MillionSongSubset/data/B/I/J/TRBIJMU12903CF892B.h5
# /home/ubuntu/MillionSongSubset/data/B/I/J/TRBIJFB128F92ED124.h5
# /home/ubuntu/MillionSongSubset/data/B/I/J/TRBIJES12903CF5B12.h5
# /home/ubuntu/MillionSongSubset/data/B/I/J/TRBIJKN12903CBF11B.h5
# /home/ubuntu/MillionSongSubset/data/B/I/J/TRBIJNF128F14815A7.h5
# /home/ubuntu/MillionSongSubset/data/B/I/J/TRBIJIP128F9334953.h5
# /home/ubuntu/MillionSongSubset/data/B/I/J/TRBIJNK128F93093EC.h5
# /home/ubuntu/MillionSongSubset/data/B/I/J/TRBIJIA128F425F57D.h5
# /home/ubuntu/MillionSongSubset/data/B/I/J/TRBIJYB128F14AE326.h5
# /home/ubuntu/MillionSongSubset/data/B/I/J/TRBIJFO128F42990C5.h5
# /home/ubuntu/MillionSongSubset/data/B/I/E/TRBIEHQ12903CB66CE.h5
# /home/ubuntu/MillionSongSubset/data/B/I/E/TRBIEXO128F429233D.h5
# /home/ubuntu/MillionSongSubset/data/B/I/E/TRBIELT128F93381E6.h5
# /home/ubuntu/MillionSongSubset/data/B/I/E/TRBIEVL128F9352A51.h5
# /home/ubuntu/MillionSongSubset/data/B/I/E/TRBIEUL128F4268D07.h5
# /home/ubuntu/MillionSongSubset/data/B/I/E/TRBIERO12903CC4BF5.h5
# /home/ubuntu/MillionSongSubset/data/B/I/E/TRBIECT128F933810B.h5
# /home/ubuntu/MillionSongSubset/data/B/I/E/TRBIEUG128F9318813.h5
# /home/ubuntu/MillionSongSubset/data/B/I/E/TRBIEJU12903CE6489.h5
# /home/ubuntu/MillionSongSubset/data/B/I/E/TRBIEGC128F93317E6.h5
# /home/ubuntu/MillionSongSubset/data/B/I/E/TRBIEZY128F426C432.h5
# /home/ubuntu/MillionSongSubset/data/B/I/E/TRBIEOB128F9345157.h5
# /home/ubuntu/MillionSongSubset/data/B/I/E/TRBIEIZ128F148D778.h5
# /home/ubuntu/MillionSongSubset/data/B/I/I/TRBIIAL128F4252C04.h5
# /home/ubuntu/MillionSongSubset/data/B/I/I/TRBIIXI128F9344121.h5
# /home/ubuntu/MillionSongSubset/data/B/I/I/TRBIIOT128F423C594.h5
# /home/ubuntu/MillionSongSubset/data/B/I/I/TRBIIJX128F933AB7D.h5
# /home/ubuntu/MillionSongSubset/data/B/I/I/TRBIIEU128F9307C88.h5
# /home/ubuntu/MillionSongSubset/data/B/I/I/TRBIICD128F14553D8.h5
# /home/ubuntu/MillionSongSubset/data/B/I/I/TRBIIJY12903CE4755.h5
# /home/ubuntu/MillionSongSubset/data/B/I/I/TRBIIUC128F931B59E.h5
# /home/ubuntu/MillionSongSubset/data/B/I/I/TRBIISJ128F14AE61C.h5
# /home/ubuntu/MillionSongSubset/data/B/I/C/TRBICQR128F9322603.h5
# /home/ubuntu/MillionSongSubset/data/B/I/C/TRBICEA128F93668AA.h5
# /home/ubuntu/MillionSongSubset/data/B/I/C/TRBICCR128F9352E4F.h5
# /home/ubuntu/MillionSongSubset/data/B/I/C/TRBICJM128F1490DE4.h5
# /home/ubuntu/MillionSongSubset/data/B/I/C/TRBICRP128F42882BB.h5
# /home/ubuntu/MillionSongSubset/data/B/I/C/TRBICVB128F9326B65.h5
# /home/ubuntu/MillionSongSubset/data/B/I/C/TRBICPL128F9303BB0.h5
# /home/ubuntu/MillionSongSubset/data/B/I/C/TRBICWB12903C9D763.h5
# /home/ubuntu/MillionSongSubset/data/B/I/C/TRBICXY128F428A9C8.h5
# /home/ubuntu/MillionSongSubset/data/B/I/C/TRBICGT128E0792473.h5
# /home/ubuntu/MillionSongSubset/data/B/I/C/TRBICDG12903CBBAC6.h5
# /home/ubuntu/MillionSongSubset/data/B/I/C/TRBICWI128F4234787.h5
# /home/ubuntu/MillionSongSubset/data/B/I/C/TRBICFZ128F429F9E1.h5
# /home/ubuntu/MillionSongSubset/data/B/I/C/TRBICHF128F92E42FA.h5
# /home/ubuntu/MillionSongSubset/data/B/I/F/TRBIFUD128F1495AE2.h5
# /home/ubuntu/MillionSongSubset/data/B/I/F/TRBIFGK128F92F23A2.h5
# /home/ubuntu/MillionSongSubset/data/B/I/F/TRBIFWB128F1460D8C.h5
# /home/ubuntu/MillionSongSubset/data/B/I/F/TRBIFPI12903CEAFB6.h5
# /home/ubuntu/MillionSongSubset/data/B/I/F/TRBIFPX12903CCF859.h5
# /home/ubuntu/MillionSongSubset/data/B/I/F/TRBIFZX128F9342AAE.h5
# /home/ubuntu/MillionSongSubset/data/B/I/F/TRBIFNO128F42702FB.h5
# /home/ubuntu/MillionSongSubset/data/B/I/F/TRBIFUV12903D07374.h5
# /home/ubuntu/MillionSongSubset/data/B/I/F/TRBIFAU128F9328EC4.h5
# /home/ubuntu/MillionSongSubset/data/B/I/F/TRBIFGL12903D0C8BE.h5
# /home/ubuntu/MillionSongSubset/data/B/I/F/TRBIFOK128EF362D20.h5
# /home/ubuntu/MillionSongSubset/data/B/I/D/TRBIDKS128F92CA8AD.h5
# /home/ubuntu/MillionSongSubset/data/B/I/D/TRBIDWY128F92E7BD9.h5
# /home/ubuntu/MillionSongSubset/data/B/I/D/TRBIDUK128F42806A4.h5
# /home/ubuntu/MillionSongSubset/data/B/I/D/TRBIDUD128F92FA11C.h5
# /home/ubuntu/MillionSongSubset/data/B/I/D/TRBIDGE128F9333791.h5
# /home/ubuntu/MillionSongSubset/data/B/I/D/TRBIDRG128F92FC6E5.h5
# /home/ubuntu/MillionSongSubset/data/B/I/D/TRBIDFH128F1464397.h5
# /home/ubuntu/MillionSongSubset/data/B/I/D/TRBIDPO128F423508A.h5
# /home/ubuntu/MillionSongSubset/data/B/I/D/TRBIDYF128F42680C4.h5
# /home/ubuntu/MillionSongSubset/data/B/I/H/TRBIHKT128F4290554.h5
# /home/ubuntu/MillionSongSubset/data/B/I/H/TRBIHGD128F92E8D12.h5
# /home/ubuntu/MillionSongSubset/data/B/I/H/TRBIHQM128F92F83BA.h5
# /home/ubuntu/MillionSongSubset/data/B/I/H/TRBIHVW128F4233965.h5
# /home/ubuntu/MillionSongSubset/data/B/I/H/TRBIHOC12903CE371C.h5
# /home/ubuntu/MillionSongSubset/data/B/I/H/TRBIHKE128F9309555.h5
# /home/ubuntu/MillionSongSubset/data/B/I/H/TRBIHAU128F425C317.h5
# /home/ubuntu/MillionSongSubset/data/B/I/H/TRBIHMZ128F42B7CF3.h5
# /home/ubuntu/MillionSongSubset/data/B/I/H/TRBIHHY128F9306343.h5
# /home/ubuntu/MillionSongSubset/data/B/I/G/TRBIGTG128F92EDBAC.h5
# /home/ubuntu/MillionSongSubset/data/B/I/G/TRBIGRU128F145B139.h5
# /home/ubuntu/MillionSongSubset/data/B/I/G/TRBIGXB12903CBFE1F.h5
# /home/ubuntu/MillionSongSubset/data/B/I/G/TRBIGLR128F92E87DD.h5
# /home/ubuntu/MillionSongSubset/data/B/I/G/TRBIGRY128F42597B3.h5
# /home/ubuntu/MillionSongSubset/data/B/I/G/TRBIGJN128F4222B19.h5
# /home/ubuntu/MillionSongSubset/data/B/I/G/TRBIGUJ128F92D674F.h5
# /home/ubuntu/MillionSongSubset/data/B/I/G/TRBIGRZ128E0792329.h5
# /home/ubuntu/MillionSongSubset/data/B/I/G/TRBIGAK128F424C305.h5
# /home/ubuntu/MillionSongSubset/data/B/I/G/TRBIGGV12903CABC77.h5
# /home/ubuntu/MillionSongSubset/data/B/I/G/TRBIGOC12903CC4FDF.h5
# /home/ubuntu/MillionSongSubset/data/B/I/G/TRBIGFQ128F933EBEE.h5
# /home/ubuntu/MillionSongSubset/data/B/I/A/TRBIAQT128F426B9E0.h5
# /home/ubuntu/MillionSongSubset/data/B/I/A/TRBIACJ128F93087A9.h5
# /home/ubuntu/MillionSongSubset/data/B/I/A/TRBIANJ128F423A53A.h5
# /home/ubuntu/MillionSongSubset/data/B/I/A/TRBIANT128F425C487.h5
# /home/ubuntu/MillionSongSubset/data/B/I/A/TRBIAKX128EF35D3BA.h5
# /home/ubuntu/MillionSongSubset/data/B/I/A/TRBIAVI128F424A89C.h5
# /home/ubuntu/MillionSongSubset/data/B/I/A/TRBIAGO128F42640FB.h5
# /home/ubuntu/MillionSongSubset/data/B/I/A/TRBIAVU128EF3493BA.h5
# /home/ubuntu/MillionSongSubset/data/B/I/A/TRBIAVP12903CEDA19.h5
# /home/ubuntu/MillionSongSubset/data/B/I/A/TRBIAHA128F42A4C9B.h5
# /home/ubuntu/MillionSongSubset/data/B/I/A/TRBIACM128F930021A.h5
# /home/ubuntu/MillionSongSubset/data/B/C/T/TRBCTEE128F42438DC.h5
# /home/ubuntu/MillionSongSubset/data/B/C/T/TRBCTRX128F4299237.h5
# /home/ubuntu/MillionSongSubset/data/B/C/T/TRBCTCQ128F427DE9A.h5
# /home/ubuntu/MillionSongSubset/data/B/C/T/TRBCTBL128F931FF29.h5
# /home/ubuntu/MillionSongSubset/data/B/C/T/TRBCTFW128F931FBE9.h5
# /home/ubuntu/MillionSongSubset/data/B/C/T/TRBCTSB128F931D570.h5
# /home/ubuntu/MillionSongSubset/data/B/C/T/TRBCTBG128F42B7E1B.h5
# /home/ubuntu/MillionSongSubset/data/B/C/T/TRBCTKV128F42222BD.h5
# /home/ubuntu/MillionSongSubset/data/B/C/S/TRBCSVE12903D13D5C.h5
# /home/ubuntu/MillionSongSubset/data/B/C/S/TRBCSHV12903CC5297.h5
# /home/ubuntu/MillionSongSubset/data/B/C/S/TRBCSYN128F92F4B62.h5
# /home/ubuntu/MillionSongSubset/data/B/C/S/TRBCSMO128F9342B20.h5
# /home/ubuntu/MillionSongSubset/data/B/C/S/TRBCSDW128F424D686.h5
# /home/ubuntu/MillionSongSubset/data/B/C/S/TRBCSAV128F933A8F8.h5
# /home/ubuntu/MillionSongSubset/data/B/C/S/TRBCSZQ128F92F9043.h5
# /home/ubuntu/MillionSongSubset/data/B/C/S/TRBCSMH128F146A146.h5
# /home/ubuntu/MillionSongSubset/data/B/C/S/TRBCSLT128F92C8260.h5
# /home/ubuntu/MillionSongSubset/data/B/C/S/TRBCSTN12903D13548.h5
# /home/ubuntu/MillionSongSubset/data/B/C/S/TRBCSPV128F4262DD7.h5
# /home/ubuntu/MillionSongSubset/data/B/C/S/TRBCSSP128F933B1D2.h5
# /home/ubuntu/MillionSongSubset/data/B/C/S/TRBCSBO128F9332822.h5
# /home/ubuntu/MillionSongSubset/data/B/C/S/TRBCSLC128F421BD25.h5
# /home/ubuntu/MillionSongSubset/data/B/C/S/TRBCSSE12903CBE261.h5
# /home/ubuntu/MillionSongSubset/data/B/C/S/TRBCSLF128E0795524.h5
# /home/ubuntu/MillionSongSubset/data/B/C/B/TRBCBMG12903CDE2A4.h5
# /home/ubuntu/MillionSongSubset/data/B/C/B/TRBCBXZ128F14628C3.h5
# /home/ubuntu/MillionSongSubset/data/B/C/B/TRBCBVO128F92D4299.h5
# /home/ubuntu/MillionSongSubset/data/B/C/B/TRBCBBR12903CA2FA7.h5
# /home/ubuntu/MillionSongSubset/data/B/C/B/TRBCBQT128F426B79A.h5
# /home/ubuntu/MillionSongSubset/data/B/C/B/TRBCBFV128E0795B94.h5
# /home/ubuntu/MillionSongSubset/data/B/C/B/TRBCBMO128F92C77B9.h5
# /home/ubuntu/MillionSongSubset/data/B/C/B/TRBCBSK12903CA2DD3.h5
# /home/ubuntu/MillionSongSubset/data/B/C/B/TRBCBLV128F14ADF31.h5
# /home/ubuntu/MillionSongSubset/data/B/C/B/TRBCBOY12903CC66C6.h5
# /home/ubuntu/MillionSongSubset/data/B/C/B/TRBCBRN128F42A1372.h5
# /home/ubuntu/MillionSongSubset/data/B/C/B/TRBCBBN128F428A232.h5
# /home/ubuntu/MillionSongSubset/data/B/C/B/TRBCBLN128F932BC9D.h5
# /home/ubuntu/MillionSongSubset/data/B/C/B/TRBCBVY128F933A195.h5
# /home/ubuntu/MillionSongSubset/data/B/C/B/TRBCBSX128F42663F2.h5
# /home/ubuntu/MillionSongSubset/data/B/C/B/TRBCBVI128F429F994.h5
# /home/ubuntu/MillionSongSubset/data/B/C/B/TRBCBYQ128F42981F1.h5
# /home/ubuntu/MillionSongSubset/data/B/C/B/TRBCBAM128F92E3044.h5
# /home/ubuntu/MillionSongSubset/data/B/C/J/TRBCJRW12903CD02BC.h5
# /home/ubuntu/MillionSongSubset/data/B/C/J/TRBCJKE12903CE3A8B.h5
# /home/ubuntu/MillionSongSubset/data/B/C/J/TRBCJQH128F93143A6.h5
# /home/ubuntu/MillionSongSubset/data/B/C/J/TRBCJTN128F42A23C2.h5
# /home/ubuntu/MillionSongSubset/data/B/C/J/TRBCJVF128F14A8A16.h5
# /home/ubuntu/MillionSongSubset/data/B/C/J/TRBCJSZ128E07969B5.h5
# /home/ubuntu/MillionSongSubset/data/B/C/J/TRBCJDC128EF35DF44.h5
# /home/ubuntu/MillionSongSubset/data/B/C/J/TRBCJIX128F424F99E.h5
# /home/ubuntu/MillionSongSubset/data/B/C/J/TRBCJQW128F4253E5F.h5
# /home/ubuntu/MillionSongSubset/data/B/C/J/TRBCJUF128F93190C2.h5
# /home/ubuntu/MillionSongSubset/data/B/C/J/TRBCJBG128F92F39AD.h5
# /home/ubuntu/MillionSongSubset/data/B/C/J/TRBCJQH128F1497A7B.h5
# /home/ubuntu/MillionSongSubset/data/B/C/E/TRBCENO128F146C85B.h5
# /home/ubuntu/MillionSongSubset/data/B/C/E/TRBCEON12903CEF0C9.h5
# /home/ubuntu/MillionSongSubset/data/B/C/E/TRBCEDV128F14AE898.h5
# /home/ubuntu/MillionSongSubset/data/B/C/E/TRBCEOA128F93090D6.h5
# /home/ubuntu/MillionSongSubset/data/B/C/E/TRBCEOS128F42A0474.h5
# /home/ubuntu/MillionSongSubset/data/B/C/E/TRBCEDT128F4260EC5.h5
# /home/ubuntu/MillionSongSubset/data/B/C/E/TRBCEYG128F1478610.h5
# /home/ubuntu/MillionSongSubset/data/B/C/E/TRBCEST128F9327FBF.h5
# /home/ubuntu/MillionSongSubset/data/B/C/E/TRBCEVJ128F428E090.h5
# /home/ubuntu/MillionSongSubset/data/B/C/E/TRBCEAB12903CA10FC.h5
# /home/ubuntu/MillionSongSubset/data/B/C/E/TRBCEDG128F9309254.h5
# /home/ubuntu/MillionSongSubset/data/B/C/N/TRBCNSM128F933D958.h5
# /home/ubuntu/MillionSongSubset/data/B/C/N/TRBCNRB128F9331CDD.h5
# /home/ubuntu/MillionSongSubset/data/B/C/N/TRBCNWM128F92D50EC.h5
# /home/ubuntu/MillionSongSubset/data/B/C/N/TRBCNUH12903CC27A5.h5
# /home/ubuntu/MillionSongSubset/data/B/C/N/TRBCNUB12903CA79C7.h5
# /home/ubuntu/MillionSongSubset/data/B/C/N/TRBCNVH128F149DCC1.h5
# /home/ubuntu/MillionSongSubset/data/B/C/N/TRBCNGI128F42597B4.h5
# /home/ubuntu/MillionSongSubset/data/B/C/N/TRBCNQN128F425AC27.h5
# /home/ubuntu/MillionSongSubset/data/B/C/N/TRBCNAJ128F934266F.h5
# /home/ubuntu/MillionSongSubset/data/B/C/N/TRBCNTP128F93530CF.h5
# /home/ubuntu/MillionSongSubset/data/B/C/I/TRBCIRO128F42B0277.h5
# /home/ubuntu/MillionSongSubset/data/B/C/I/TRBCIJF12903CF15F3.h5
# /home/ubuntu/MillionSongSubset/data/B/C/I/TRBCIBA128F934E298.h5
# /home/ubuntu/MillionSongSubset/data/B/C/I/TRBCIEV12903CE60F1.h5
# /home/ubuntu/MillionSongSubset/data/B/C/I/TRBCIDR128F92D36B2.h5
# /home/ubuntu/MillionSongSubset/data/B/C/I/TRBCIXP128F14A3016.h5
# /home/ubuntu/MillionSongSubset/data/B/C/I/TRBCIQL128F427C0AD.h5
# /home/ubuntu/MillionSongSubset/data/B/C/I/TRBCIVP12903CF9688.h5
# /home/ubuntu/MillionSongSubset/data/B/C/I/TRBCICD12903CF2BA9.h5
# /home/ubuntu/MillionSongSubset/data/B/C/I/TRBCIGC128F4249CE6.h5
# /home/ubuntu/MillionSongSubset/data/B/C/I/TRBCIUW128F92F6F3D.h5
# /home/ubuntu/MillionSongSubset/data/B/C/I/TRBCISZ128F92E9CEF.h5
# /home/ubuntu/MillionSongSubset/data/B/C/I/TRBCIDU12903CA2F54.h5
# /home/ubuntu/MillionSongSubset/data/B/C/I/TRBCIXV128F4261F09.h5
# /home/ubuntu/MillionSongSubset/data/B/C/I/TRBCIDX128F422F215.h5
# /home/ubuntu/MillionSongSubset/data/B/C/C/TRBCCEG128F9321406.h5
# /home/ubuntu/MillionSongSubset/data/B/C/C/TRBCCAJ128F148CBBB.h5
# /home/ubuntu/MillionSongSubset/data/B/C/C/TRBCCLU12903CDBAC4.h5
# /home/ubuntu/MillionSongSubset/data/B/C/C/TRBCCJV128F92F23B0.h5
# /home/ubuntu/MillionSongSubset/data/B/C/C/TRBCCQR128F92FA11A.h5
# /home/ubuntu/MillionSongSubset/data/B/C/C/TRBCCWW128F933F246.h5
# /home/ubuntu/MillionSongSubset/data/B/C/C/TRBCCYW12903CEC282.h5
# /home/ubuntu/MillionSongSubset/data/B/C/C/TRBCCAP12903CDE877.h5
# /home/ubuntu/MillionSongSubset/data/B/C/P/TRBCPXR128F42AC544.h5
# /home/ubuntu/MillionSongSubset/data/B/C/P/TRBCPKL128F42A97A4.h5
# /home/ubuntu/MillionSongSubset/data/B/C/P/TRBCPIP12903CB81D4.h5
# /home/ubuntu/MillionSongSubset/data/B/C/P/TRBCPTO12903CBBFD9.h5
# /home/ubuntu/MillionSongSubset/data/B/C/L/TRBCLIO128F426E4B8.h5
# /home/ubuntu/MillionSongSubset/data/B/C/L/TRBCLFF128F92F09CB.h5
# /home/ubuntu/MillionSongSubset/data/B/C/L/TRBCLUS128F92EA61B.h5
# /home/ubuntu/MillionSongSubset/data/B/C/L/TRBCLFK128F931A46E.h5
# /home/ubuntu/MillionSongSubset/data/B/C/L/TRBCLGH12903CCA1D0.h5
# /home/ubuntu/MillionSongSubset/data/B/C/U/TRBCUWM128F92FDD7E.h5
# /home/ubuntu/MillionSongSubset/data/B/C/U/TRBCUMB128F14AD232.h5
# /home/ubuntu/MillionSongSubset/data/B/C/U/TRBCUIV128F9309077.h5
# /home/ubuntu/MillionSongSubset/data/B/C/U/TRBCURH12903CAD622.h5
# ...
# /home/ubuntu/MillionSongSubset/data/A/E/D/TRAEDCT12903CD9238.h5
# /home/ubuntu/MillionSongSubset/data/A/E/D/TRAEDXO128F421B908.h5
# /home/ubuntu/MillionSongSubset/data/A/E/D/TRAEDYD128F425A868.h5
# /home/ubuntu/MillionSongSubset/data/A/E/D/TRAEDPP128F42AFB64.h5
# /home/ubuntu/MillionSongSubset/data/A/E/D/TRAEDJW128F422B4CB.h5
# /home/ubuntu/MillionSongSubset/data/A/E/K/TRAEKCV128E0781A5B.h5
# /home/ubuntu/MillionSongSubset/data/A/E/K/TRAEKIO128F425786C.h5
# /home/ubuntu/MillionSongSubset/data/A/E/K/TRAEKCR128F14593A5.h5
# /home/ubuntu/MillionSongSubset/data/A/E/Z/TRAEZAZ128F930608E.h5
# /home/ubuntu/MillionSongSubset/data/A/E/Z/TRAEZMX128F425C3CE.h5
# /home/ubuntu/MillionSongSubset/data/A/E/Z/TRAEZWE128F4244505.h5
# /home/ubuntu/MillionSongSubset/data/A/E/Z/TRAEZKA128F4282B79.h5
# /home/ubuntu/MillionSongSubset/data/A/E/Z/TRAEZLQ128F427F954.h5
# /home/ubuntu/MillionSongSubset/data/A/E/Z/TRAEZFJ128F422A5C0.h5
# /home/ubuntu/MillionSongSubset/data/A/E/H/TRAEHTU128F93353E5.h5
# /home/ubuntu/MillionSongSubset/data/A/E/H/TRAEHYF128F148AE0C.h5
# /home/ubuntu/MillionSongSubset/data/A/E/H/TRAEHBW12903CE1045.h5
# /home/ubuntu/MillionSongSubset/data/A/E/H/TRAEHTT128F9303492.h5
# /home/ubuntu/MillionSongSubset/data/A/E/H/TRAEHXW128F146F3C5.h5
# /home/ubuntu/MillionSongSubset/data/A/E/H/TRAEHOI12903CD02C8.h5
# /home/ubuntu/MillionSongSubset/data/A/E/H/TRAEHTK128F14A4706.h5
# /home/ubuntu/MillionSongSubset/data/A/E/H/TRAEHLP128F933720D.h5
# /home/ubuntu/MillionSongSubset/data/A/E/H/TRAEHMP128F92DCC42.h5
# /home/ubuntu/MillionSongSubset/data/A/E/H/TRAEHNA128F423786C.h5
# /home/ubuntu/MillionSongSubset/data/A/E/M/TRAEMRI128F425F33D.h5
# /home/ubuntu/MillionSongSubset/data/A/E/M/TRAEMTU128EF363016.h5
# /home/ubuntu/MillionSongSubset/data/A/E/M/TRAEMDH128F146B548.h5
# /home/ubuntu/MillionSongSubset/data/A/E/M/TRAEMGG12903CEBB52.h5
# /home/ubuntu/MillionSongSubset/data/A/E/M/TRAEMAA128F428E58F.h5
# /home/ubuntu/MillionSongSubset/data/A/E/M/TRAEMZE128F426EB6B.h5
# /home/ubuntu/MillionSongSubset/data/A/E/M/TRAEMNZ128F9334662.h5
# /home/ubuntu/MillionSongSubset/data/A/E/M/TRAEMKJ12903C9D211.h5
# /home/ubuntu/MillionSongSubset/data/A/E/M/TRAEMGL128F4266177.h5
# /home/ubuntu/MillionSongSubset/data/A/E/M/TRAEMXB128F429FA26.h5
# /home/ubuntu/MillionSongSubset/data/A/E/M/TRAEMZO12903CC525F.h5
# /home/ubuntu/MillionSongSubset/data/A/E/M/TRAEMZW128F148406D.h5
# /home/ubuntu/MillionSongSubset/data/A/E/M/TRAEMMB128F426A1BF.h5
# /home/ubuntu/MillionSongSubset/data/A/E/O/TRAEOFB12903CB7900.h5
# /home/ubuntu/MillionSongSubset/data/A/E/O/TRAEOGF128F423896A.h5
# /home/ubuntu/MillionSongSubset/data/A/E/O/TRAEOFD128F9311409.h5
# /home/ubuntu/MillionSongSubset/data/A/E/O/TRAEOMT128F92FE852.h5
# /home/ubuntu/MillionSongSubset/data/A/E/O/TRAEOGO128F93302B9.h5
# /home/ubuntu/MillionSongSubset/data/A/E/O/TRAEOMS128F4262357.h5
# /home/ubuntu/MillionSongSubset/data/A/E/O/TRAEOUM128F42915ED.h5
# /home/ubuntu/MillionSongSubset/data/A/E/O/TRAEOUJ128EF352F8B.h5
# /home/ubuntu/MillionSongSubset/data/A/E/O/TRAEOUE128F93187B9.h5
# /home/ubuntu/MillionSongSubset/data/A/E/O/TRAEOED128EF36659C.h5
# /home/ubuntu/MillionSongSubset/data/A/E/O/TRAEOUQ128F9322E73.h5
# /home/ubuntu/MillionSongSubset/data/A/E/O/TRAEOOH128F934ACD4.h5
# /home/ubuntu/MillionSongSubset/data/A/E/O/TRAEOVG12903CEDD3A.h5
# /home/ubuntu/MillionSongSubset/data/A/E/O/TRAEOAW128F4280F8E.h5
# /home/ubuntu/MillionSongSubset/data/A/E/O/TRAEOIC12903D05C54.h5
# /home/ubuntu/MillionSongSubset/data/A/E/O/TRAEOPH128F932E302.h5
# /home/ubuntu/MillionSongSubset/data/A/E/O/TRAEOBA12903CAFAB0.h5
# /home/ubuntu/MillionSongSubset/data/A/E/O/TRAEOHK128F932F77A.h5
# /home/ubuntu/MillionSongSubset/data/A/E/X/TRAEXSE128F4249171.h5
# /home/ubuntu/MillionSongSubset/data/A/E/X/TRAEXEA128F933C67D.h5
# /home/ubuntu/MillionSongSubset/data/A/E/X/TRAEXNK128F14901F8.h5
# /home/ubuntu/MillionSongSubset/data/A/E/X/TRAEXXT128F427AF12.h5
# /home/ubuntu/MillionSongSubset/data/A/E/X/TRAEXLG128F932B2EC.h5
# /home/ubuntu/MillionSongSubset/data/A/E/X/TRAEXHW128F92E2602.h5
# /home/ubuntu/MillionSongSubset/data/A/E/X/TRAEXYP128F4231193.h5
# /home/ubuntu/MillionSongSubset/data/A/E/X/TRAEXTM128E07811E1.h5
# /home/ubuntu/MillionSongSubset/data/A/E/X/TRAEXAN128EF354542.h5
# /home/ubuntu/MillionSongSubset/data/A/E/X/TRAEXGP128F4283791.h5
# /home/ubuntu/MillionSongSubset/data/A/E/G/TRAEGHJ12903CE26DF.h5
# /home/ubuntu/MillionSongSubset/data/A/E/G/TRAEGMO128F146D5F6.h5
# /home/ubuntu/MillionSongSubset/data/A/E/G/TRAEGKP12903CBB66B.h5
# /home/ubuntu/MillionSongSubset/data/A/E/G/TRAEGJE128F42656F1.h5
# /home/ubuntu/MillionSongSubset/data/A/E/G/TRAEGMN128F42690CD.h5
# /home/ubuntu/MillionSongSubset/data/A/E/G/TRAEGAZ128F426240C.h5
# /home/ubuntu/MillionSongSubset/data/A/E/G/TRAEGGV128F92F29B2.h5
# /home/ubuntu/MillionSongSubset/data/A/E/G/TRAEGDO128F42705BF.h5
# /home/ubuntu/MillionSongSubset/data/A/E/G/TRAEGUL128E078B0C1.h5
# /home/ubuntu/MillionSongSubset/data/A/E/G/TRAEGBE128F4284973.h5
# /home/ubuntu/MillionSongSubset/data/A/E/G/TRAEGRR128F422285F.h5
# /home/ubuntu/MillionSongSubset/data/A/E/G/TRAEGRU128F9358874.h5
# /home/ubuntu/MillionSongSubset/data/A/E/G/TRAEGRF128F426B2D2.h5
# /home/ubuntu/MillionSongSubset/data/A/E/G/TRAEGFX12903CF8E7B.h5
# /home/ubuntu/MillionSongSubset/data/A/E/W/TRAEWKQ128F427C3EC.h5
# /home/ubuntu/MillionSongSubset/data/A/E/W/TRAEWUR128F1456EAB.h5
# /home/ubuntu/MillionSongSubset/data/A/E/W/TRAEWEC128F421F5D9.h5
# /home/ubuntu/MillionSongSubset/data/A/E/W/TRAEWVG128F428AC7F.h5
# /home/ubuntu/MillionSongSubset/data/A/E/W/TRAEWUW128F42710A4.h5
# /home/ubuntu/MillionSongSubset/data/A/E/W/TRAEWLF128F42B1F89.h5
# /home/ubuntu/MillionSongSubset/data/A/E/W/TRAEWXY128E0786183.h5
# /home/ubuntu/MillionSongSubset/data/A/E/W/TRAEWHH128F428F3AB.h5
# /home/ubuntu/MillionSongSubset/data/A/E/W/TRAEWYQ128F9306C38.h5
# /home/ubuntu/MillionSongSubset/data/A/E/W/TRAEWKS12903CB651D.h5
# /home/ubuntu/MillionSongSubset/data/A/E/W/TRAEWQN128F4286306.h5
# /home/ubuntu/MillionSongSubset/data/A/E/W/TRAEWQP128F9330AF7.h5
# /home/ubuntu/MillionSongSubset/data/A/E/W/TRAEWGT128F930A556.h5
# /home/ubuntu/MillionSongSubset/data/A/E/W/TRAEWQV128F427B9B2.h5
# /home/ubuntu/MillionSongSubset/data/A/E/W/TRAEWMF128F93080BE.h5
# /home/ubuntu/MillionSongSubset/data/A/E/A/TRAEACU128F933D7C1.h5
# /home/ubuntu/MillionSongSubset/data/A/E/A/TRAEATZ128F426E5C8.h5
# /home/ubuntu/MillionSongSubset/data/A/E/A/TRAEAEV128F1493757.h5
# /home/ubuntu/MillionSongSubset/data/A/E/A/TRAEASY128F148247C.h5
# /home/ubuntu/MillionSongSubset/data/A/E/A/TRAEAVH128F4270D4C.h5
# /home/ubuntu/MillionSongSubset/data/A/E/A/TRAEADE128F423BEF8.h5
# /home/ubuntu/MillionSongSubset/data/A/E/A/TRAEASB12903CD48BC.h5
# /home/ubuntu/MillionSongSubset/data/A/E/A/TRAEAST128F42931B1.h5
# /home/ubuntu/MillionSongSubset/data/A/E/A/TRAEABT128F931984D.h5
# /home/ubuntu/MillionSongSubset/data/A/E/A/TRAEAZV12903D0CBA6.h5
# /home/ubuntu/MillionSongSubset/data/A/E/A/TRAEALX12903CB5701.h5
# /home/ubuntu/MillionSongSubset/data/A/E/A/TRAEARU128E0781A02.h5
# /home/ubuntu/MillionSongSubset/data/A/E/A/TRAEADK128F4270AA6.h5
# /home/ubuntu/MillionSongSubset/data/A/E/A/TRAEATL128F42690A7.h5
# /home/ubuntu/MillionSongSubset/data/A/N/T/TRANTAI12903CBA0E5.h5
# /home/ubuntu/MillionSongSubset/data/A/N/T/TRANTAN128E078B326.h5
# /home/ubuntu/MillionSongSubset/data/A/N/T/TRANTOT128F428ACD8.h5
# /home/ubuntu/MillionSongSubset/data/A/N/T/TRANTFR128F931C7DA.h5
# /home/ubuntu/MillionSongSubset/data/A/N/T/TRANTID128F9331448.h5
# /home/ubuntu/MillionSongSubset/data/A/N/T/TRANTJK128F92E5935.h5
# /home/ubuntu/MillionSongSubset/data/A/N/T/TRANTRC128F9355329.h5
# /home/ubuntu/MillionSongSubset/data/A/N/T/TRANTMY128F92D3536.h5
# /home/ubuntu/MillionSongSubset/data/A/N/T/TRANTPG128F4276789.h5
# /home/ubuntu/MillionSongSubset/data/A/N/T/TRANTFV128F428447A.h5
# /home/ubuntu/MillionSongSubset/data/A/N/T/TRANTAD128F92FD042.h5
# /home/ubuntu/MillionSongSubset/data/A/N/T/TRANTEO128F429B51B.h5
# /home/ubuntu/MillionSongSubset/data/A/N/T/TRANTCK128F428AC39.h5
# /home/ubuntu/MillionSongSubset/data/A/N/S/TRANSDL128F93507B9.h5
# /home/ubuntu/MillionSongSubset/data/A/N/S/TRANSYV128F428A00C.h5
# /home/ubuntu/MillionSongSubset/data/A/N/S/TRANSGS128F9303A11.h5
# /home/ubuntu/MillionSongSubset/data/A/N/S/TRANSLD12903CE137C.h5
# /home/ubuntu/MillionSongSubset/data/A/N/S/TRANSAG12903CEBAED.h5
# /home/ubuntu/MillionSongSubset/data/A/N/S/TRANSKF128F147FCB4.h5
# /home/ubuntu/MillionSongSubset/data/A/N/S/TRANSAK128F933071E.h5
# /home/ubuntu/MillionSongSubset/data/A/N/S/TRANSVK128F423842C.h5
# /home/ubuntu/MillionSongSubset/data/A/N/S/TRANSUM128F92E8DF3.h5
# /home/ubuntu/MillionSongSubset/data/A/N/S/TRANSSH128F4231393.h5
# /home/ubuntu/MillionSongSubset/data/A/N/S/TRANSUK128F9337DF7.h5
# /home/ubuntu/MillionSongSubset/data/A/N/B/TRANBWB128F429FB03.h5
# /home/ubuntu/MillionSongSubset/data/A/N/B/TRANBWC128F92E240A.h5
# /home/ubuntu/MillionSongSubset/data/A/N/B/TRANBRL12903CED03D.h5
# /home/ubuntu/MillionSongSubset/data/A/N/B/TRANBMY128F426416A.h5
# /home/ubuntu/MillionSongSubset/data/A/N/B/TRANBUW128F933C645.h5
# /home/ubuntu/MillionSongSubset/data/A/N/B/TRANBNU12903CA02FA.h5
# /home/ubuntu/MillionSongSubset/data/A/N/J/TRANJJM128F4267B03.h5
# /home/ubuntu/MillionSongSubset/data/A/N/J/TRANJWP128F428560C.h5
# /home/ubuntu/MillionSongSubset/data/A/N/J/TRANJGM128F427A41B.h5
# /home/ubuntu/MillionSongSubset/data/A/N/J/TRANJMB128F42926E4.h5
# /home/ubuntu/MillionSongSubset/data/A/N/J/TRANJSV128E0799689.h5
# /home/ubuntu/MillionSongSubset/data/A/N/J/TRANJMO128F425C44D.h5
# /home/ubuntu/MillionSongSubset/data/A/N/J/TRANJPA128F92CAE02.h5
# /home/ubuntu/MillionSongSubset/data/A/N/E/TRANEMQ128F42A10A8.h5
# /home/ubuntu/MillionSongSubset/data/A/N/E/TRANEQC12903D01CE6.h5
# /home/ubuntu/MillionSongSubset/data/A/N/E/TRANEHV12903CD1E33.h5
# /home/ubuntu/MillionSongSubset/data/A/N/E/TRANEQB128F4284978.h5
# /home/ubuntu/MillionSongSubset/data/A/N/E/TRANELD128F4250FCF.h5
# /home/ubuntu/MillionSongSubset/data/A/N/E/TRANELB128F92EF58A.h5
# /home/ubuntu/MillionSongSubset/data/A/N/E/TRANELG128F424F264.h5
# /home/ubuntu/MillionSongSubset/data/A/N/E/TRANEYV128F4269032.h5
# /home/ubuntu/MillionSongSubset/data/A/N/E/TRANEMF128F42888C8.h5
# /home/ubuntu/MillionSongSubset/data/A/N/N/TRANNJC128F429F7E3.h5
# /home/ubuntu/MillionSongSubset/data/A/N/N/TRANNCH128F14B1A75.h5
# /home/ubuntu/MillionSongSubset/data/A/N/N/TRANNUW128F931B513.h5
# /home/ubuntu/MillionSongSubset/data/A/N/N/TRANNZZ128F92C22F7.h5
# /home/ubuntu/MillionSongSubset/data/A/N/N/TRANNLE128E07871BF.h5
# /home/ubuntu/MillionSongSubset/data/A/N/N/TRANNSL128F92E1C57.h5
# /home/ubuntu/MillionSongSubset/data/A/N/N/TRANNCZ128F92F1D22.h5
# /home/ubuntu/MillionSongSubset/data/A/N/N/TRANNXH128F933A6B3.h5
# /home/ubuntu/MillionSongSubset/data/A/N/N/TRANNES128F4277849.h5
# /home/ubuntu/MillionSongSubset/data/A/N/N/TRANNDV128F427FDD8.h5
# /home/ubuntu/MillionSongSubset/data/A/N/I/TRANIAH12903CA9482.h5
# /home/ubuntu/MillionSongSubset/data/A/N/I/TRANIJG128F92EFC9B.h5
# /home/ubuntu/MillionSongSubset/data/A/N/I/TRANIWL128F4262AB0.h5
# /home/ubuntu/MillionSongSubset/data/A/N/I/TRANIBF12903CFA420.h5
# /home/ubuntu/MillionSongSubset/data/A/N/I/TRANIQV128F425423F.h5
# /home/ubuntu/MillionSongSubset/data/A/N/I/TRANIVG128F1484DED.h5
# /home/ubuntu/MillionSongSubset/data/A/N/I/TRANINJ128F93480C6.h5
# /home/ubuntu/MillionSongSubset/data/A/N/I/TRANIUD12903CCE692.h5
# /home/ubuntu/MillionSongSubset/data/A/N/I/TRANIJF128F422E570.h5
# /home/ubuntu/MillionSongSubset/data/A/N/I/TRANIFM128F931C027.h5
# /home/ubuntu/MillionSongSubset/data/A/N/I/TRANIZO128F9335764.h5
# /home/ubuntu/MillionSongSubset/data/A/N/I/TRANIMO12903CA55C7.h5
# /home/ubuntu/MillionSongSubset/data/A/N/I/TRANIHL128F42970BD.h5
# /home/ubuntu/MillionSongSubset/data/A/N/I/TRANIWM128F1495AB7.h5
# /home/ubuntu/MillionSongSubset/data/A/N/I/TRANIUS12903D00EC7.h5
# /home/ubuntu/MillionSongSubset/data/A/N/I/TRANIJQ128F4298A10.h5
# /home/ubuntu/MillionSongSubset/data/A/N/I/TRANIPA128F93151A2.h5
# /home/ubuntu/MillionSongSubset/data/A/N/C/TRANCCN128E0794B18.h5
# /home/ubuntu/MillionSongSubset/data/A/N/C/TRANCRD12903CDE242.h5
# /home/ubuntu/MillionSongSubset/data/A/N/C/TRANCFU128F42307F9.h5
# /home/ubuntu/MillionSongSubset/data/A/N/C/TRANCSE128F93044F1.h5
# /home/ubuntu/MillionSongSubset/data/A/N/C/TRANCFS12903C9B61B.h5
# /home/ubuntu/MillionSongSubset/data/A/N/C/TRANCVS12903CDDC84.h5
# /home/ubuntu/MillionSongSubset/data/A/N/C/TRANCFZ128F4252AB4.h5
# /home/ubuntu/MillionSongSubset/data/A/N/C/TRANCCR12903C9CF6B.h5
# /home/ubuntu/MillionSongSubset/data/A/N/C/TRANCEE128F4267C92.h5
# /home/ubuntu/MillionSongSubset/data/A/N/C/TRANCJG128F14528B4.h5
# /home/ubuntu/MillionSongSubset/data/A/N/C/TRANCEY12903CF8C34.h5
# /home/ubuntu/MillionSongSubset/data/A/N/C/TRANCOS128F4267DFB.h5
# /home/ubuntu/MillionSongSubset/data/A/N/C/TRANCOH128F422F31D.h5
# /home/ubuntu/MillionSongSubset/data/A/N/C/TRANCWY12903C9C82C.h5
# /home/ubuntu/MillionSongSubset/data/A/N/P/TRANPXL128F42B8FED.h5
# /home/ubuntu/MillionSongSubset/data/A/N/P/TRANPFD12903CEA1A9.h5
# /home/ubuntu/MillionSongSubset/data/A/N/P/TRANPRQ128EF348E34.h5
# /home/ubuntu/MillionSongSubset/data/A/N/P/TRANPLF128F9340B6E.h5
# /home/ubuntu/MillionSongSubset/data/A/N/P/TRANPLE128F9322D6F.h5
# /home/ubuntu/MillionSongSubset/data/A/N/P/TRANPHV128F9344CC3.h5
# /home/ubuntu/MillionSongSubset/data/A/N/P/TRANPRZ128F92FD7B1.h5
# /home/ubuntu/MillionSongSubset/data/A/N/P/TRANPFB128F9310D69.h5
# /home/ubuntu/MillionSongSubset/data/A/N/P/TRANPUZ128F422B236.h5
# /home/ubuntu/MillionSongSubset/data/A/N/P/TRANPKC128F93486B9.h5
# /home/ubuntu/MillionSongSubset/data/A/N/P/TRANPYL128F9316AE7.h5
# /home/ubuntu/MillionSongSubset/data/A/N/P/TRANPLD128F92EB034.h5
# /home/ubuntu/MillionSongSubset/data/A/N/P/TRANPAA128F92F10F8.h5
# /home/ubuntu/MillionSongSubset/data/A/N/P/TRANPDG128F930F4FE.h5
# /home/ubuntu/MillionSongSubset/data/A/N/P/TRANPFP128F932C002.h5
# /home/ubuntu/MillionSongSubset/data/A/N/P/TRANPWV128F9341281.h5
# /home/ubuntu/MillionSongSubset/data/A/N/P/TRANPYC128F9332A49.h5
# /home/ubuntu/MillionSongSubset/data/A/N/P/TRANPPB128F42962D4.h5
# /home/ubuntu/MillionSongSubset/data/A/N/L/TRANLQA128F930F8F8.h5
# /home/ubuntu/MillionSongSubset/data/A/N/L/TRANLMB12903CA8250.h5
# /home/ubuntu/MillionSongSubset/data/A/N/L/TRANLHJ128F9313CA4.h5
# /home/ubuntu/MillionSongSubset/data/A/N/L/TRANLXB128F92FE4F4.h5
# /home/ubuntu/MillionSongSubset/data/A/N/L/TRANLRX128F4259030.h5
# /home/ubuntu/MillionSongSubset/data/A/N/L/TRANLHL12903CF88E5.h5
# /home/ubuntu/MillionSongSubset/data/A/N/L/TRANLYF128F1491D3B.h5
# /home/ubuntu/MillionSongSubset/data/A/N/L/TRANLJA128F42A5379.h5
# /home/ubuntu/MillionSongSubset/data/A/N/L/TRANLLL128F42268D9.h5
# /home/ubuntu/MillionSongSubset/data/A/N/L/TRANLIQ12903CF98AE.h5
# /home/ubuntu/MillionSongSubset/data/A/N/L/TRANLSP128F14671CA.h5
# /home/ubuntu/MillionSongSubset/data/A/N/L/TRANLLT128F4226A66.h5
# /home/ubuntu/MillionSongSubset/data/A/N/U/TRANUUU12903CD4347.h5
# /home/ubuntu/MillionSongSubset/data/A/N/U/TRANUKR128F427643B.h5
# /home/ubuntu/MillionSongSubset/data/A/N/U/TRANUVH12903D1059F.h5
# /home/ubuntu/MillionSongSubset/data/A/N/U/TRANUQO128F14991ED.h5
# /home/ubuntu/MillionSongSubset/data/A/N/U/TRANUME128E0789D4C.h5
# /home/ubuntu/MillionSongSubset/data/A/N/U/TRANUNR12903CE6E2E.h5
# /home/ubuntu/MillionSongSubset/data/A/N/U/TRANUSN128F4281594.h5
# /home/ubuntu/MillionSongSubset/data/A/N/U/TRANUUK128E0788284.h5
# /home/ubuntu/MillionSongSubset/data/A/N/U/TRANUPI12903CA6A4F.h5
# /home/ubuntu/MillionSongSubset/data/A/N/U/TRANUSB128F9343695.h5
# /home/ubuntu/MillionSongSubset/data/A/N/U/TRANULO128F422E6FE.h5
# /home/ubuntu/MillionSongSubset/data/A/N/U/TRANUEV128F4282392.h5
# /home/ubuntu/MillionSongSubset/data/A/N/U/TRANUTE128F148B17C.h5
# /home/ubuntu/MillionSongSubset/data/A/N/Q/TRANQBJ12903CAFF20.h5
# /home/ubuntu/MillionSongSubset/data/A/N/Q/TRANQDN128F425EEEA.h5
# /home/ubuntu/MillionSongSubset/data/A/N/Q/TRANQRQ12903CC4BBB.h5
# /home/ubuntu/MillionSongSubset/data/A/N/Q/TRANQZI128F14901EE.h5
# /home/ubuntu/MillionSongSubset/data/A/N/Q/TRANQCI128F9327BD7.h5
# /home/ubuntu/MillionSongSubset/data/A/N/Q/TRANQKF12903CDEC7A.h5
# /home/ubuntu/MillionSongSubset/data/A/N/Q/TRANQLL128F92F5263.h5
# /home/ubuntu/MillionSongSubset/data/A/N/Q/TRANQYI12903CA2BA9.h5
# /home/ubuntu/MillionSongSubset/data/A/N/Q/TRANQEQ128F428AD70.h5
# /home/ubuntu/MillionSongSubset/data/A/N/Q/TRANQEB128F92C46CC.h5
# /home/ubuntu/MillionSongSubset/data/A/N/Q/TRANQDS12903CE3E1D.h5
# /home/ubuntu/MillionSongSubset/data/A/N/Q/TRANQNS128F42739D1.h5

# %%
#msd_df = sqlContext.createDataFrame(zip(song_number, album_id, artist_latitude, artist_location, artist_longitude, artist_name, danceability, duration, energy, key_signature, key_signature_confidence, song_id, tempo, song_hotttnesss, time_signature, time_signature_confidence, title, year), schema=['song_number', 'album_id', 'artist_latitude', 'artist_location', 'artist_longitude', 'artist_name', 'danceability', 'duration', 'energy', 'key_signature', 'key_signature_confidence', 'song_id', 'tempo', 'song_hotttnesss', 'time_signature', 'time_signature_confidence', 'title', 'year'])

# %%
msd_df.show()
# Out:
# +-----------+--------+---------------+--------------------+----------------+--------------------+------------+---------+------+-------------+------------------------+--------------------+-------+-------------------+--------------+-------------------------+--------------------+----+
# |song_number|album_id|artist_latitude|     artist_location|artist_longitude|         artist_name|danceability| duration|energy|key_signature|key_signature_confidence|             song_id|  tempo|    song_hotttnesss|time_signature|time_signature_confidence|               title|year|
# +-----------+--------+---------------+--------------------+----------------+--------------------+------------+---------+------+-------------+------------------------+--------------------+-------+-------------------+--------------+-------------------------+--------------------+----+
# |          1|  511272|               |                 b''|                |          b'Dickies'|         0.0|179.59138|   0.0|          2.0|                   0.277|b'SONKOFE12AB0187...| 70.183| 0.6536286823546584|           4.0|                    0.293|         b'Gigantor'|   0|
# |          2|   35970|               |                 b''|                |b'IMISKOUBRIA fea...|         0.0|245.26322|   0.0|         10.0|                   0.421|b'SOHZYBG12A58291...|100.003|                NaN|           4.0|                      1.0|b'Apoliome Re Gio...|   0|
# |          3|   14979|       18.11526|          b'Jamaica'|       -77.27348| b'Cornell Campbell'|         0.0|184.99873|   0.0|         11.0|                   0.424|b'SOLFRCH12A67021...|141.257|                NaN|           4.0|                    0.517|b'Got To Tell The...|1997|
# |          4|  647420|       33.71197|      b'Lithonia GA'|       -84.10599|       b'Brenda Lee'|         0.0|173.06077|   0.0|          8.0|                   0.637|b'SOGOBIT12AB0189...|124.291|0.38293509007501925|           1.0|                      0.0|b"If I'M Dreaming...|   0|
# |          5|  395388|               |b'New York NY [Qu...|                |b'Capone-N-Noreag...|         0.0| 256.1824|   0.0|          0.0|                     1.0|b'SOACXUA12AB017C...|201.494| 0.4623799459732465|           4.0|                    0.819|           b'Rotate'|2009|
# |          6|   69802|       40.58751|       b'Redding CA'|      -122.39293|       b'Roy Rogers'|         0.0| 185.0771|   0.0|          0.0|                   0.524|b'SOTBDNQ12A67ADB...|100.451| 0.2530973283167317|           3.0|                    0.699|b"The Hills Of Ol...|   0|
# |          7|  597519|               |       b'Jackson MS'|                |       b'Faith Hill'|         0.0|207.80363|   0.0|          0.0|                   0.441|b'SOQAUIF12AC4686...|141.705| 0.5177890440253479|           4.0|                    0.472|b'Better Days (Al...|1998|
# |          8|  813022|       40.71455|b'NY - New York C...|       -74.00712|  b'George Schuller'|         0.0| 409.0771|   0.0|          7.0|                   0.259|b'SOTVMJI12AB0186...|103.022|                0.0|           3.0|                    0.792|   b'Distant Cousin'|   0|
# |          9|  236680|               |                 b''|                |            b'Opals'|         0.0|136.77669|   0.0|          5.0|                   0.754|b'SOAQRFQ12A8AE46...|155.611|                NaN|           3.0|                      1.0|             b'Love'|   0|
# |         10|  116947|               |           b'POLAND'|                |         b'Behemoth'|         0.0|206.44526|   0.0|          6.0|                   0.525|b'SOKZCJC12AF72A8...|114.929| 0.6204583740756491|           3.0|                      1.0|  b'Here And Beyond'|2002|
# |         11|  123609|       48.39023|     b'Brest France'|        -4.48622|          b'Miossec'|         0.0|225.90649|   0.0|          2.0|                   0.613|b'SOWOWTL12A6D4F9...| 89.013|                NaN|           3.0|                    0.706|b'D\xc3\xa9sol\xc...|2004|
# |         12|  348099|               |b'Shelby North Ca...|                |       b'Don Gibson'|         0.0|151.09179|   0.0|          9.0|                   0.624|b'SOPFIWM12AB0186...| 81.832|                NaN|           3.0|                    0.898|b'(Prayer Is The ...|1959|
# |         13|   28491|               |b'Toronto Ontario...|                |   b'Dream Warriors'|         0.0|414.24934|   0.0|          6.0|                   0.005|b'SOAEGFO12A6D4F8...|106.821|                NaN|           5.0|                      1.0|b'Sound Clash (fe...|1996|
# |         14|   54098|               |                 b''|                |          b'Mau Mau'|         0.0|745.40363|   0.0|          7.0|                   0.687|b'SOLWGCZ12A6D4FA...|107.983|                NaN|           4.0|                      1.0|b'Finisterre (Live)'|   0|
# |         15|  491293|               |      b'Wilmette IL'|                |     b'Fall Out Boy'|         0.0|214.33424|   0.0|          2.0|                   0.439|b'SODWYJZ12AB0182...|160.109| 0.7876204040717483|           4.0|                     0.47|b"America's Suite...|2008|
# |         16|  536493|       35.83073|       b'Dunedin FL'|       -85.97874|       b'Lari White'|         0.0|239.90812|   0.0|          7.0|                   0.722|b'SODKKPS12AB0183...|137.002|                NaN|           4.0|                    0.075|b'The One Who Liv...|   0|
# |         17|  206616|               |                 b''|                |            b'Dakis'|         0.0|224.07791|   0.0|          0.0|                   0.586|b'SOVBBUZ12A8C137...| 109.08|                NaN|           4.0|                    0.855|b'Tsai Me Lemoni ...|   0|
# |         18|  599225|               |                 b''|                |   b'Steven Halpern'|         0.0|248.63302|   0.0|          5.0|                     0.4|b'SOIWQSF12AC468C...|134.538|                NaN|           3.0|                    0.356|b'Natural Light (...|   0|
# |         19|  727695|               |                 b''|                |        b'Slackbaba'|         0.0| 465.6322|   0.0|          0.0|                    0.67|b'SOCWFVT12AB0189...| 88.644| 0.5524570090077631|           5.0|                    0.607|     b'Sea of Green'|2006|
# |         20|  624432|       52.47859|b'Birmingham Engl...|         -1.9086|            b'Frost'|         0.0|336.24771|   0.0|          0.0|                   0.954|b'SOTZIPQ12AB0180...|126.946|                NaN|           3.0|                    0.207|b'My Plastic Hear...|   0|
# +-----------+--------+---------------+--------------------+----------------+--------------------+------------+---------+------+-------------+------------------------+--------------------+-------+-------------------+--------------+-------------------------+--------------------+----+
# only showing top 20 rows

# %%
msd_df.printSchema()
# Out:
# root
#  |-- song_number: long (nullable = true)
#  |-- album_id: string (nullable = true)
#  |-- artist_latitude: string (nullable = true)
#  |-- artist_location: string (nullable = true)
#  |-- artist_longitude: string (nullable = true)
#  |-- artist_name: string (nullable = true)
#  |-- danceability: double (nullable = true)
#  |-- duration: double (nullable = true)
#  |-- energy: double (nullable = true)
#  |-- key_signature: double (nullable = true)
#  |-- key_signature_confidence: double (nullable = true)
#  |-- song_id: string (nullable = true)
#  |-- tempo: double (nullable = true)
#  |-- song_hotttnesss: double (nullable = true)
#  |-- time_signature: double (nullable = true)
#  |-- time_signature_confidence: double (nullable = true)
#  |-- title: string (nullable = true)
#  |-- year: string (nullable = true)

# %%
start_time = time.time()

# %%
msd_df = msd_df.na.fill(0)
msd_df1 = msd_df.filter(msd_df['song_hotttnesss'] > 0).agg(avg(col("song_hotttnesss"))).collect()

# %%
average = rowUnpack(msd_df1)
average = average['avg(song_hotttnesss)']

msd_df_corrected = msd_df.withColumn("song_hotttnesss", \
              when(msd_df["song_hotttnesss"] == 0, average).otherwise(msd_df["song_hotttnesss"]))

# %%
msd_df_corrected.show()
# Out:
# +-----------+--------+---------------+--------------------+----------------+--------------------+------------+---------+------+-------------+------------------------+--------------------+-------+-------------------+--------------+-------------------------+--------------------+----+
# |song_number|album_id|artist_latitude|     artist_location|artist_longitude|         artist_name|danceability| duration|energy|key_signature|key_signature_confidence|             song_id|  tempo|    song_hotttnesss|time_signature|time_signature_confidence|               title|year|
# +-----------+--------+---------------+--------------------+----------------+--------------------+------------+---------+------+-------------+------------------------+--------------------+-------+-------------------+--------------+-------------------------+--------------------+----+
# |          1|  511272|               |                 b''|                |          b'Dickies'|         0.0|179.59138|   0.0|          2.0|                   0.277|b'SONKOFE12AB0187...| 70.183| 0.6536286823546584|           4.0|                    0.293|         b'Gigantor'|   0|
# |          2|   35970|               |                 b''|                |b'IMISKOUBRIA fea...|         0.0|245.26322|   0.0|         10.0|                   0.421|b'SOHZYBG12A58291...|100.003|0.45948195643562095|           4.0|                      1.0|b'Apoliome Re Gio...|   0|
# |          3|   14979|       18.11526|          b'Jamaica'|       -77.27348| b'Cornell Campbell'|         0.0|184.99873|   0.0|         11.0|                   0.424|b'SOLFRCH12A67021...|141.257|0.45948195643562095|           4.0|                    0.517|b'Got To Tell The...|1997|
# |          4|  647420|       33.71197|      b'Lithonia GA'|       -84.10599|       b'Brenda Lee'|         0.0|173.06077|   0.0|          8.0|                   0.637|b'SOGOBIT12AB0189...|124.291|0.38293509007501925|           1.0|                      0.0|b"If I'M Dreaming...|   0|
# |          5|  395388|               |b'New York NY [Qu...|                |b'Capone-N-Noreag...|         0.0| 256.1824|   0.0|          0.0|                     1.0|b'SOACXUA12AB017C...|201.494| 0.4623799459732465|           4.0|                    0.819|           b'Rotate'|2009|
# |          6|   69802|       40.58751|       b'Redding CA'|      -122.39293|       b'Roy Rogers'|         0.0| 185.0771|   0.0|          0.0|                   0.524|b'SOTBDNQ12A67ADB...|100.451| 0.2530973283167317|           3.0|                    0.699|b"The Hills Of Ol...|   0|
# |          7|  597519|               |       b'Jackson MS'|                |       b'Faith Hill'|         0.0|207.80363|   0.0|          0.0|                   0.441|b'SOQAUIF12AC4686...|141.705| 0.5177890440253479|           4.0|                    0.472|b'Better Days (Al...|1998|
# |          8|  813022|       40.71455|b'NY - New York C...|       -74.00712|  b'George Schuller'|         0.0| 409.0771|   0.0|          7.0|                   0.259|b'SOTVMJI12AB0186...|103.022|0.45948195643562095|           3.0|                    0.792|   b'Distant Cousin'|   0|
# |          9|  236680|               |                 b''|                |            b'Opals'|         0.0|136.77669|   0.0|          5.0|                   0.754|b'SOAQRFQ12A8AE46...|155.611|0.45948195643562095|           3.0|                      1.0|             b'Love'|   0|
# |         10|  116947|               |           b'POLAND'|                |         b'Behemoth'|         0.0|206.44526|   0.0|          6.0|                   0.525|b'SOKZCJC12AF72A8...|114.929| 0.6204583740756491|           3.0|                      1.0|  b'Here And Beyond'|2002|
# |         11|  123609|       48.39023|     b'Brest France'|        -4.48622|          b'Miossec'|         0.0|225.90649|   0.0|          2.0|                   0.613|b'SOWOWTL12A6D4F9...| 89.013|0.45948195643562095|           3.0|                    0.706|b'D\xc3\xa9sol\xc...|2004|
# |         12|  348099|               |b'Shelby North Ca...|                |       b'Don Gibson'|         0.0|151.09179|   0.0|          9.0|                   0.624|b'SOPFIWM12AB0186...| 81.832|0.45948195643562095|           3.0|                    0.898|b'(Prayer Is The ...|1959|
# |         13|   28491|               |b'Toronto Ontario...|                |   b'Dream Warriors'|         0.0|414.24934|   0.0|          6.0|                   0.005|b'SOAEGFO12A6D4F8...|106.821|0.45948195643562095|           5.0|                      1.0|b'Sound Clash (fe...|1996|
# |         14|   54098|               |                 b''|                |          b'Mau Mau'|         0.0|745.40363|   0.0|          7.0|                   0.687|b'SOLWGCZ12A6D4FA...|107.983|0.45948195643562095|           4.0|                      1.0|b'Finisterre (Live)'|   0|
# |         15|  491293|               |      b'Wilmette IL'|                |     b'Fall Out Boy'|         0.0|214.33424|   0.0|          2.0|                   0.439|b'SODWYJZ12AB0182...|160.109| 0.7876204040717483|           4.0|                     0.47|b"America's Suite...|2008|
# |         16|  536493|       35.83073|       b'Dunedin FL'|       -85.97874|       b'Lari White'|         0.0|239.90812|   0.0|          7.0|                   0.722|b'SODKKPS12AB0183...|137.002|0.45948195643562095|           4.0|                    0.075|b'The One Who Liv...|   0|
# |         17|  206616|               |                 b''|                |            b'Dakis'|         0.0|224.07791|   0.0|          0.0|                   0.586|b'SOVBBUZ12A8C137...| 109.08|0.45948195643562095|           4.0|                    0.855|b'Tsai Me Lemoni ...|   0|
# |         18|  599225|               |                 b''|                |   b'Steven Halpern'|         0.0|248.63302|   0.0|          5.0|                     0.4|b'SOIWQSF12AC468C...|134.538|0.45948195643562095|           3.0|                    0.356|b'Natural Light (...|   0|
# |         19|  727695|               |                 b''|                |        b'Slackbaba'|         0.0| 465.6322|   0.0|          0.0|                    0.67|b'SOCWFVT12AB0189...| 88.644| 0.5524570090077631|           5.0|                    0.607|     b'Sea of Green'|2006|
# |         20|  624432|       52.47859|b'Birmingham Engl...|         -1.9086|            b'Frost'|         0.0|336.24771|   0.0|          0.0|                   0.954|b'SOTZIPQ12AB0180...|126.946|0.45948195643562095|           3.0|                    0.207|b'My Plastic Hear...|   0|
# +-----------+--------+---------------+--------------------+----------------+--------------------+------------+---------+------+-------------+------------------------+--------------------+-------+-------------------+--------------+-------------------------+--------------------+----+
# only showing top 20 rows

# %%
msd_df_sub = msd_df_corrected.select("duration","key_signature","tempo","time_signature","song_hotttnesss")
#msd_df_sub.show()

# %%
msd_sort = msd_df_sub.orderBy('duration', ascending=True)
#msd_sort.show()

# %%
(training_data, test_data) = msd_sort.randomSplit([0.7, 0.3])
training_data =training_data.rdd.map(lambda x: LabeledPoint(x[4], x[:4]))
test_data =test_data.rdd.map(lambda x: LabeledPoint(x[4], x[:4]))

#training_data.take(5)
#test_data.take(5)

# %%
model = DecisionTree.trainRegressor(training_data, categoricalFeaturesInfo={},
                                    impurity='variance', maxDepth=5, maxBins=32)

# %%
model_tree = model.toDebugString()

predictions = model.predict(test_data.map(lambda x: x.features))
labelsAndPredictions = test_data.map(lambda lp: lp.label).zip(predictions)

testMSE = labelsAndPredictions.map(lambda lp: (lp[0] - lp[1]) * (lp[0] - lp[1])).sum() / float(test_data.count())
end_time = time.time()
exec_time = end_time - start_time
print('Test Mean Squared Error = ' + str(testMSE))

# %%
print("--- %s seconds ---" % exec_time)
# Out:
# --- 29.352632999420166 seconds ---

# %%
input_cols = ["duration","key_signature","tempo","time_signature"]

for i, feat in enumerate(input_cols):
    model_tree = model_tree.replace('feature ' + str(i), feat)

print('Learned regression tree model: \n')
print(model_tree)
# Out:
# Learned regression tree model:
#
# DecisionTreeModel regressor of depth 5 with 53 nodes
#   If (tempo <= 84.288)
#    If (time_signature <= 0.5)
#     If (key_signature <= 0.5)
#      Predict: 0.45948195643562095
#     Else (key_signature > 0.5)
#      If (duration <= 233.65179)
#       Predict: 0.6034409947366194
#      Else (duration > 233.65179)
#       Predict: 0.693947934490814
#    Else (time_signature > 0.5)
#     If (key_signature <= 0.5)
#      If (time_signature <= 3.5)
#       If (duration <= 275.526075)
#        Predict: 0.40774666297059986
#       Else (duration > 275.526075)
#        Predict: 0.4720855202729366
#      Else (time_signature > 3.5)
#       If (duration <= 245.4722)
#        Predict: 0.467170884496594
#       Else (duration > 245.4722)
#        Predict: 0.5124946748064468
#     Else (key_signature > 0.5)
#      If (tempo <= 66.869)
#       If (duration <= 206.95465000000002)
#        Predict: 0.4545419509003757
#       Else (duration > 206.95465000000002)
#        Predict: 0.43767098447536906
#      Else (tempo > 66.869)
#       If (time_signature <= 3.5)
#        Predict: 0.4228461603771183
#       Else (time_signature > 3.5)
#        Predict: 0.4409123159818147
#   Else (tempo > 84.288)
#    If (tempo <= 122.09649999999999)
#     If (tempo <= 116.98349999999999)
#      If (time_signature <= 3.5)
#       If (tempo <= 113.622)
#        Predict: 0.44759954590466294
#       Else (tempo > 113.622)
#        Predict: 0.4760064716739917
#      Else (time_signature > 3.5)
#       If (duration <= 206.95465000000002)
#        Predict: 0.45343918745264344
#       Else (duration > 206.95465000000002)
#        Predict: 0.466916740247854
#     Else (tempo > 116.98349999999999)
#      If (key_signature <= 4.5)
#       If (duration <= 481.27955)
#        Predict: 0.43320745204582567
#       Else (duration > 481.27955)
#        Predict: 0.48958001538921964
#      Else (key_signature > 4.5)
#       If (duration <= 331.34975)
#        Predict: 0.4555827030461825
#       Else (duration > 331.34975)
#        Predict: 0.4262692643025066
#    Else (tempo > 122.09649999999999)
#     If (duration <= 401.44934)
#      If (tempo <= 196.3865)
#       If (duration <= 183.00036)
#        Predict: 0.46013910595668744
#       Else (duration > 183.00036)
#        Predict: 0.4674494256725955
#      Else (tempo > 196.3865)
#       If (key_signature <= 5.5)
#        Predict: 0.49763685701719695
#       Else (key_signature > 5.5)
#        Predict: 0.4670600418944801
#     Else (duration > 401.44934)
#      If (key_signature <= 1.5)
#       If (tempo <= 158.83499999999998)
#        Predict: 0.41906921469408004
#       Else (tempo > 158.83499999999998)
#        Predict: 0.48337895078630055
#      Else (key_signature > 1.5)
#       If (tempo <= 196.3865)
#        Predict: 0.46106609968015616
#       Else (tempo > 196.3865)
#        Predict: 0.4060421128673915

# %%
spark_context.stop()

# %%
#model.save(spark_context, "/home/ubuntu/MillionSongLDSA")
#sameModel = DecisionTreeModel.load(sc, "target/tmp/myDecisionTreeRegressionModel")
